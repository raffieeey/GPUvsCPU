# %% [markdown]
# <a href="https://colab.research.google.com/github/raffieeey/MiscStuff/blob/master/Ames_housing_wide_and_deep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tf-nightly-gpu-2.0-preview

# %% [markdown]
# ## Ames Housing Price Regression with a Wide and Deep Model
#
# This example includes:
#
# - Parsing and vectorization of a structured dataset containing both numerical features and categorical features.
# - Handling missing values.
# - Data normalization.
# - Building and training a wide-and-deep model for regression.
# - Decoding model predictions.

# %% [markdown]
# ## Download and unzip the data

# %%
# !wget https://s3.amazonaws.com/keras-datasets/ames-housing-dataset.zip
# Out:
# --2019-06-03 18:25:55--  https://s3.amazonaws.com/keras-datasets/ames-housing-dataset.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.21.181
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.21.181|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182871 (179K) [application/zip]
# Saving to: ‘ames-housing-dataset.zip’
#
# ames-housing-datase 100%[===================>] 178.58K  --.-KB/s    in 0.08s
#
# 2019-06-03 18:25:56 (2.07 MB/s) - ‘ames-housing-dataset.zip’ saved [182871/182871]

# %%
# !unzip ames-housing-dataset.zip
# Out:
# Archive:  ames-housing-dataset.zip
#   inflating: AmesHousing.csv

# %% [markdown]
# ## Load the data in Pandas and list the columns

# %%
import pandas as pd
import numpy as np

dataframe = pd.read_csv('AmesHousing.csv')

# %%
print('Columns:', list(enumerate(dataframe.columns)))
# Out:
# Columns: [(0, 'Order'), (1, 'PID'), (2, 'MS SubClass'), (3, 'MS Zoning'), (4, 'Lot Frontage'), (5, 'Lot Area'), (6, 'Street'), (7, 'Alley'), (8, 'Lot Shape'), (9, 'Land Contour'), (10, 'Utilities'), (11, 'Lot Config'), (12, 'Land Slope'), (13, 'Neighborhood'), (14, 'Condition 1'), (15, 'Condition 2'), (16, 'Bldg Type'), (17, 'House Style'), (18, 'Overall Qual'), (19, 'Overall Cond'), (20, 'Year Built'), (21, 'Year Remod/Add'), (22, 'Roof Style'), (23, 'Roof Matl'), (24, 'Exterior 1st'), (25, 'Exterior 2nd'), (26, 'Mas Vnr Type'), (27, 'Mas Vnr Area'), (28, 'Exter Qual'), (29, 'Exter Cond'), (30, 'Foundation'), (31, 'Bsmt Qual'), (32, 'Bsmt Cond'), (33, 'Bsmt Exposure'), (34, 'BsmtFin Type 1'), (35, 'BsmtFin SF 1'), (36, 'BsmtFin Type 2'), (37, 'BsmtFin SF 2'), (38, 'Bsmt Unf SF'), (39, 'Total Bsmt SF'), (40, 'Heating'), (41, 'Heating QC'), (42, 'Central Air'), (43, 'Electrical'), (44, '1st Flr SF'), (45, '2nd Flr SF'), (46, 'Low Qual Fin SF'), (47, 'Gr Liv Area'), (48, 'Bsmt Full Bath'), (49, 'Bsmt Half Bath'), (50, 'Full Bath'), (51, 'Half Bath'), (52, 'Bedroom AbvGr'), (53, 'Kitchen AbvGr'), (54, 'Kitchen Qual'), (55, 'TotRms AbvGrd'), (56, 'Functional'), (57, 'Fireplaces'), (58, 'Fireplace Qu'), (59, 'Garage Type'), (60, 'Garage Yr Blt'), (61, 'Garage Finish'), (62, 'Garage Cars'), (63, 'Garage Area'), (64, 'Garage Qual'), (65, 'Garage Cond'), (66, 'Paved Drive'), (67, 'Wood Deck SF'), (68, 'Open Porch SF'), (69, 'Enclosed Porch'), (70, '3Ssn Porch'), (71, 'Screen Porch'), (72, 'Pool Area'), (73, 'Pool QC'), (74, 'Fence'), (75, 'Misc Feature'), (76, 'Misc Val'), (77, 'Mo Sold'), (78, 'Yr Sold'), (79, 'Sale Type'), (80, 'Sale Condition'), (81, 'SalePrice')]

# %% [markdown]
# Columns "Order" and "PID" are not features and need to be filtered out. Column "SalePrice" contains the target we need to predict for each sample.

# %% [markdown]
# ## Vectorize targets

# %%
targets = dataframe['SalePrice'].values.astype('float32')
print('targets.shape:', targets.shape)
# Out:
# targets.shape: (2930,)

# %% [markdown]
# ## Vectorize features
#
# There are two kinds of features in this dataset:
#
# - Numerical features: a number associated with each sample. For instance, "Lot Area" is a numerical feature.
# - Categorical features: a string value associated with each sample. For instance, "MS Zoning" is a categorical feature.

# %%
dataframe['Lot Area'][:5]
# Out:
# 0    31770
# 1    11622
# 2    14267
# 3    11160
# 4    13830
# Name: Lot Area, dtype: int64

# %%
dataframe['MS Zoning'][:5]
# Out:
# 0    RL
# 1    RH
# 2    RL
# 3    RL
# 4    RL
# Name: MS Zoning, dtype: object

# %% [markdown]
# We vectorize each numerical feature by using Panda's `values` accessor, and casting the resulting Numpy array to float32.
#
# We vectorize each categorical feature by:
#
# - Making a list of the different possible values taken by this feature, and how many times each value occurs.
# - Filtering out values with fewer than 50 occurences.
# - One-hot encoding the remaining values.
#
# One-hot encoding is done by assigning an index to each value, then encoding the feature for sample as an array that is all-zeros except for the index of the value taken by this sample.
#
# For instance, if you have 3 possible vales, "val1", "val2", and "val3", we could assign the following indices:
#
# `{'val1': 0, 'val2': 1, 'val3': 2}`
#
# then a sample with value "val2" would be encoded as:
#
# `[0, 1, 0]`
#
# and a sample with value "val3" would be encoded as:
#
# `[0, 0, 1]`
#
# If a sample has an empty entry for this feature, or has a value that was filtered out (i.e. not one of `{'val1', 'val2', 'val3'}`), we would encode it as:
#
# `[0, 0, 0]`.

# %%
SKIP_VALUES_WITH_FEWER_OCCURENCES_THAN = 50

def vectorize_column(column):
  print('Processing column: "%s"' % column.name)
  dtype = column.dtype
  if np.issubdtype(dtype, np.number):
    print('...numerical column')
    array = vectorize_numerical_column(column)
  else:
    print('...categorical column')
    array = vectorize_categorical_column(column)
  print('...shape:', array.shape)
  print('-')
  return array

  
def vectorize_numerical_column(column):
  return np.expand_dims(column.values, -1).astype('float32')


def vectorize_categorical_column(column):
  print('...value counts:')
  print(column.value_counts())
  
  # Filter values that occur at least SKIP_VALUES_WITH_FEWER_OCCURENCES_THAN
  # and assign an integer index to each of these values (for one-hot encoding).
  value_index = {}
  for value, count in column.value_counts().items():
    if count >= SKIP_VALUES_WITH_FEWER_OCCURENCES_THAN:
      value_index[value] = len(value_index)
  # Note that our `value_index` 
  print('...kept values:', list(value_index.keys()))
  
  # One-hot encode the filtered values.
  array = np.zeros(shape=(len(column), len(value_index)), dtype='float32')
  for i, value in enumerate(column):
    if value in value_index:
      index = value_index[value]
      array[i, index] = 1.
  return array

# %%
column_arrays = []
# We exclude column 0 and 1 (not informative) and the last column (targets)
for name in dataframe.columns[2:-1]:
  array = vectorize_column(dataframe[name])
  column_arrays.append(array)

features = np.concatenate(column_arrays, axis=-1)
print('features shape: %s' % (features.shape,))
# Out:
# Processing column: "MS SubClass"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "MS Zoning"
# ...categorical column
# ...value counts:
# RL         2273
# RM          462
# FV          139
# RH           27
# C (all)      25
# I (all)       2
# A (agr)       2
# Name: MS Zoning, dtype: int64
# ...kept values: ['RL', 'RM', 'FV']
# ...shape: (2930, 3)
# -
# Processing column: "Lot Frontage"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Lot Area"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Street"
# ...categorical column
# ...value counts:
# Pave    2918
# Grvl      12
# Name: Street, dtype: int64
# ...kept values: ['Pave']
# ...shape: (2930, 1)
# -
# Processing column: "Alley"
# ...categorical column
# ...value counts:
# Grvl    120
# Pave     78
# Name: Alley, dtype: int64
# ...kept values: ['Grvl', 'Pave']
# ...shape: (2930, 2)
# -
# Processing column: "Lot Shape"
# ...categorical column
# ...value counts:
# Reg    1859
# IR1     979
# IR2      76
# IR3      16
# Name: Lot Shape, dtype: int64
# ...kept values: ['Reg', 'IR1', 'IR2']
# ...shape: (2930, 3)
# -
# Processing column: "Land Contour"
# ...categorical column
# ...value counts:
# Lvl    2633
# HLS     120
# Bnk     117
# Low      60
# Name: Land Contour, dtype: int64
# ...kept values: ['Lvl', 'HLS', 'Bnk', 'Low']
# ...shape: (2930, 4)
# -
# Processing column: "Utilities"
# ...categorical column
# ...value counts:
# AllPub    2927
# NoSewr       2
# NoSeWa       1
# Name: Utilities, dtype: int64
# ...kept values: ['AllPub']
# ...shape: (2930, 1)
# -
# Processing column: "Lot Config"
# ...categorical column
# ...value counts:
# Inside     2140
# Corner      511
# CulDSac     180
# FR2          85
# FR3          14
# Name: Lot Config, dtype: int64
# ...kept values: ['Inside', 'Corner', 'CulDSac', 'FR2']
# ...shape: (2930, 4)
# -
# Processing column: "Land Slope"
# ...categorical column
# ...value counts:
# Gtl    2789
# Mod     125
# Sev      16
# Name: Land Slope, dtype: int64
# ...kept values: ['Gtl', 'Mod']
# ...shape: (2930, 2)
# -
# Processing column: "Neighborhood"
# ...categorical column
# ...value counts:
# NAmes      443
# CollgCr    267
# OldTown    239
# Edwards    194
# Somerst    182
# NridgHt    166
# Gilbert    165
# Sawyer     151
# NWAmes     131
# SawyerW    125
# Mitchel    114
# BrkSide    108
# Crawfor    103
# IDOTRR      93
# Timber      72
# NoRidge     71
# StoneBr     51
# SWISU       48
# ClearCr     44
# MeadowV     37
# BrDale      30
# Blmngtn     28
# Veenker     24
# NPkVill     23
# Blueste     10
# Greens       8
# GrnHill      2
# Landmrk      1
# Name: Neighborhood, dtype: int64
# ...kept values: ['NAmes', 'CollgCr', 'OldTown', 'Edwards', 'Somerst', 'NridgHt', 'Gilbert', 'Sawyer', 'NWAmes', 'SawyerW', 'Mitchel', 'BrkSide', 'Crawfor', 'IDOTRR', 'Timber', 'NoRidge', 'StoneBr']
# ...shape: (2930, 17)
# -
# Processing column: "Condition 1"
# ...categorical column
# ...value counts:
# Norm      2522
# Feedr      164
# Artery      92
# RRAn        50
# PosN        39
# RRAe        28
# PosA        20
# RRNn         9
# RRNe         6
# Name: Condition 1, dtype: int64
# ...kept values: ['Norm', 'Feedr', 'Artery', 'RRAn']
# ...shape: (2930, 4)
# -
# Processing column: "Condition 2"
# ...categorical column
# ...value counts:
# Norm      2900
# Feedr       13
# Artery       5
# PosA         4
# PosN         4
# RRNn         2
# RRAn         1
# RRAe         1
# Name: Condition 2, dtype: int64
# ...kept values: ['Norm']
# ...shape: (2930, 1)
# -
# Processing column: "Bldg Type"
# ...categorical column
# ...value counts:
# 1Fam      2425
# TwnhsE     233
# Duplex     109
# Twnhs      101
# 2fmCon      62
# Name: Bldg Type, dtype: int64
# ...kept values: ['1Fam', 'TwnhsE', 'Duplex', 'Twnhs', '2fmCon']
# ...shape: (2930, 5)
# -
# Processing column: "House Style"
# ...categorical column
# ...value counts:
# 1Story    1481
# 2Story     873
# 1.5Fin     314
# SLvl       128
# SFoyer      83
# 2.5Unf      24
# 1.5Unf      19
# 2.5Fin       8
# Name: House Style, dtype: int64
# ...kept values: ['1Story', '2Story', '1.5Fin', 'SLvl', 'SFoyer']
# ...shape: (2930, 5)
# -
# Processing column: "Overall Qual"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Overall Cond"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Year Built"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Year Remod/Add"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Roof Style"
# ...categorical column
# ...value counts:
# Gable      2321
# Hip         551
# Gambrel      22
# Flat         20
# Mansard      11
# Shed          5
# Name: Roof Style, dtype: int64
# ...kept values: ['Gable', 'Hip']
# ...shape: (2930, 2)
# -
# Processing column: "Roof Matl"
# ...categorical column
# ...value counts:
# CompShg    2887
# Tar&Grv      23
# WdShake       9
# WdShngl       7
# Membran       1
# ClyTile       1
# Metal         1
# Roll          1
# Name: Roof Matl, dtype: int64
# ...kept values: ['CompShg']
# ...shape: (2930, 1)
# -
# Processing column: "Exterior 1st"
# ...categorical column
# ...value counts:
# VinylSd    1026
# MetalSd     450
# HdBoard     442
# Wd Sdng     420
# Plywood     221
# CemntBd     126
# BrkFace      88
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# AsphShn       2
# Stone         2
# CBlock        2
# ImStucc       1
# PreCast       1
# Name: Exterior 1st, dtype: int64
# ...kept values: ['VinylSd', 'MetalSd', 'HdBoard', 'Wd Sdng', 'Plywood', 'CemntBd', 'BrkFace', 'WdShing']
# ...shape: (2930, 8)
# -
# Processing column: "Exterior 2nd"
# ...categorical column
# ...value counts:
# VinylSd    1015
# MetalSd     447
# HdBoard     406
# Wd Sdng     397
# Plywood     274
# CmentBd     126
# Wd Shng      81
# Stucco       47
# BrkFace      47
# AsbShng      38
# Brk Cmn      22
# ImStucc      15
# Stone         6
# AsphShn       4
# CBlock        3
# PreCast       1
# Other         1
# Name: Exterior 2nd, dtype: int64
# ...kept values: ['VinylSd', 'MetalSd', 'HdBoard', 'Wd Sdng', 'Plywood', 'CmentBd', 'Wd Shng']
# ...shape: (2930, 7)
# -
# Processing column: "Mas Vnr Type"
# ...categorical column
# ...value counts:
# None       1752
# BrkFace     880
# Stone       249
# BrkCmn       25
# CBlock        1
# Name: Mas Vnr Type, dtype: int64
# ...kept values: ['None', 'BrkFace', 'Stone']
# ...shape: (2930, 3)
# -
# Processing column: "Mas Vnr Area"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Exter Qual"
# ...categorical column
# ...value counts:
# TA    1799
# Gd     989
# Ex     107
# Fa      35
# Name: Exter Qual, dtype: int64
# ...kept values: ['TA', 'Gd', 'Ex']
# ...shape: (2930, 3)
# -
# Processing column: "Exter Cond"
# ...categorical column
# ...value counts:
# TA    2549
# Gd     299
# Fa      67
# Ex      12
# Po       3
# Name: Exter Cond, dtype: int64
# ...kept values: ['TA', 'Gd', 'Fa']
# ...shape: (2930, 3)
# -
# Processing column: "Foundation"
# ...categorical column
# ...value counts:
# PConc     1310
# CBlock    1244
# BrkTil     311
# Slab        49
# Stone       11
# Wood         5
# Name: Foundation, dtype: int64
# ...kept values: ['PConc', 'CBlock', 'BrkTil']
# ...shape: (2930, 3)
# -
# Processing column: "Bsmt Qual"
# ...categorical column
# ...value counts:
# TA    1283
# Gd    1219
# Ex     258
# Fa      88
# Po       2
# Name: Bsmt Qual, dtype: int64
# ...kept values: ['TA', 'Gd', 'Ex', 'Fa']
# ...shape: (2930, 4)
# -
# Processing column: "Bsmt Cond"
# ...categorical column
# ...value counts:
# TA    2616
# Gd     122
# Fa     104
# Po       5
# Ex       3
# Name: Bsmt Cond, dtype: int64
# ...kept values: ['TA', 'Gd', 'Fa']
# ...shape: (2930, 3)
# -
# Processing column: "Bsmt Exposure"
# ...categorical column
# ...value counts:
# No    1906
# Av     418
# Gd     284
# Mn     239
# Name: Bsmt Exposure, dtype: int64
# ...kept values: ['No', 'Av', 'Gd', 'Mn']
# ...shape: (2930, 4)
# -
# Processing column: "BsmtFin Type 1"
# ...categorical column
# ...value counts:
# GLQ    859
# Unf    851
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# Name: BsmtFin Type 1, dtype: int64
# ...kept values: ['GLQ', 'Unf', 'ALQ', 'Rec', 'BLQ', 'LwQ']
# ...shape: (2930, 6)
# -
# Processing column: "BsmtFin SF 1"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "BsmtFin Type 2"
# ...categorical column
# ...value counts:
# Unf    2499
# Rec     106
# LwQ      89
# BLQ      68
# ALQ      53
# GLQ      34
# Name: BsmtFin Type 2, dtype: int64
# ...kept values: ['Unf', 'Rec', 'LwQ', 'BLQ', 'ALQ']
# ...shape: (2930, 5)
# -
# Processing column: "BsmtFin SF 2"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Bsmt Unf SF"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Total Bsmt SF"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Heating"
# ...categorical column
# ...value counts:
# GasA     2885
# GasW       27
# Grav        9
# Wall        6
# OthW        2
# Floor       1
# Name: Heating, dtype: int64
# ...kept values: ['GasA']
# ...shape: (2930, 1)
# -
# Processing column: "Heating QC"
# ...categorical column
# ...value counts:
# Ex    1495
# TA     864
# Gd     476
# Fa      92
# Po       3
# Name: Heating QC, dtype: int64
# ...kept values: ['Ex', 'TA', 'Gd', 'Fa']
# ...shape: (2930, 4)
# -
# Processing column: "Central Air"
# ...categorical column
# ...value counts:
# Y    2734
# N     196
# Name: Central Air, dtype: int64
# ...kept values: ['Y', 'N']
# ...shape: (2930, 2)
# -
# Processing column: "Electrical"
# ...categorical column
# ...value counts:
# SBrkr    2682
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: Electrical, dtype: int64
# ...kept values: ['SBrkr', 'FuseA', 'FuseF']
# ...shape: (2930, 3)
# -
# Processing column: "1st Flr SF"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "2nd Flr SF"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Low Qual Fin SF"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Gr Liv Area"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Bsmt Full Bath"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Bsmt Half Bath"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Full Bath"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Half Bath"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Bedroom AbvGr"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Kitchen AbvGr"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Kitchen Qual"
# ...categorical column
# ...value counts:
# TA    1494
# Gd    1160
# Ex     205
# Fa      70
# Po       1
# Name: Kitchen Qual, dtype: int64
# ...kept values: ['TA', 'Gd', 'Ex', 'Fa']
# ...shape: (2930, 4)
# -
# Processing column: "TotRms AbvGrd"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Functional"
# ...categorical column
# ...value counts:
# Typ     2728
# Min2      70
# Min1      65
# Mod       35
# Maj1      19
# Maj2       9
# Sev        2
# Sal        2
# Name: Functional, dtype: int64
# ...kept values: ['Typ', 'Min2', 'Min1']
# ...shape: (2930, 3)
# -
# Processing column: "Fireplaces"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Fireplace Qu"
# ...categorical column
# ...value counts:
# Gd    744
# TA    600
# Fa     75
# Po     46
# Ex     43
# Name: Fireplace Qu, dtype: int64
# ...kept values: ['Gd', 'TA', 'Fa']
# ...shape: (2930, 3)
# -
# Processing column: "Garage Type"
# ...categorical column
# ...value counts:
# Attchd     1731
# Detchd      782
# BuiltIn     186
# Basment      36
# 2Types       23
# CarPort      15
# Name: Garage Type, dtype: int64
# ...kept values: ['Attchd', 'Detchd', 'BuiltIn']
# ...shape: (2930, 3)
# -
# Processing column: "Garage Yr Blt"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Garage Finish"
# ...categorical column
# ...value counts:
# Unf    1231
# RFn     812
# Fin     728
# Name: Garage Finish, dtype: int64
# ...kept values: ['Unf', 'RFn', 'Fin']
# ...shape: (2930, 3)
# -
# Processing column: "Garage Cars"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Garage Area"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Garage Qual"
# ...categorical column
# ...value counts:
# TA    2615
# Fa     124
# Gd      24
# Po       5
# Ex       3
# Name: Garage Qual, dtype: int64
# ...kept values: ['TA', 'Fa']
# ...shape: (2930, 2)
# -
# Processing column: "Garage Cond"
# ...categorical column
# ...value counts:
# TA    2665
# Fa      74
# Gd      15
# Po      14
# Ex       3
# Name: Garage Cond, dtype: int64
# ...kept values: ['TA', 'Fa']
# ...shape: (2930, 2)
# -
# Processing column: "Paved Drive"
# ...categorical column
# ...value counts:
# Y    2652
# N     216
# P      62
# Name: Paved Drive, dtype: int64
# ...kept values: ['Y', 'N', 'P']
# ...shape: (2930, 3)
# -
# Processing column: "Wood Deck SF"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Open Porch SF"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Enclosed Porch"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "3Ssn Porch"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Screen Porch"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Pool Area"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Pool QC"
# ...categorical column
# ...value counts:
# Ex    4
# Gd    4
# TA    3
# Fa    2
# Name: Pool QC, dtype: int64
# ...kept values: []
# ...shape: (2930, 0)
# -
# Processing column: "Fence"
# ...categorical column
# ...value counts:
# MnPrv    330
# GdPrv    118
# GdWo     112
# MnWw      12
# Name: Fence, dtype: int64
# ...kept values: ['MnPrv', 'GdPrv', 'GdWo']
# ...shape: (2930, 3)
# -
# Processing column: "Misc Feature"
# ...categorical column
# ...value counts:
# Shed    95
# Gar2     5
# Othr     4
# Elev     1
# TenC     1
# Name: Misc Feature, dtype: int64
# ...kept values: ['Shed']
# ...shape: (2930, 1)
# -
# Processing column: "Misc Val"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Mo Sold"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Yr Sold"
# ...numerical column
# ...shape: (2930, 1)
# -
# Processing column: "Sale Type"
# ...categorical column
# ...value counts:
# WD       2536
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# VWD         1
# Name: Sale Type, dtype: int64
# ...kept values: ['WD ', 'New', 'COD']
# ...shape: (2930, 3)
# -
# Processing column: "Sale Condition"
# ...categorical column
# ...value counts:
# Normal     2413
# Partial     245
# Abnorml     190
# Family       46
# Alloca       24
# AdjLand      12
# Name: Sale Condition, dtype: int64
# ...kept values: ['Normal', 'Partial', 'Abnorml']
# ...shape: (2930, 3)
# -
# features shape: (2930, 183)

# %% [markdown]
# ## Split data into a training set and a validation set

# %%
num_val_samples = int(len(features) * 0.2)

train_features = features[:-num_val_samples]
train_targets = targets[:-num_val_samples]

val_features = features[-num_val_samples:]
val_targets = targets[-num_val_samples:]

# %%
print('Number of training samples:', len(train_features))
print('Number of validation samples:', len(val_features))
# Out:
# Number of training samples: 2344
# Number of validation samples: 586

# %% [markdown]
# ## Replace missing values with mean of column
#
# Some numerical columns apparently contain NaN values (corresponding to missing entries):

# %%
nan_indices = np.where(np.isnan(train_features))
print('Number of NaN entries in train_features:', len(np.unique(nan_indices)))
# Out:
# Number of NaN entries in train_features: 547

# %% [markdown]
# We replace them with the mean of their column. We do this using the handy Numpy utility `np.nanmean`., to compute the mean of the columns while excluding NaN values (otherwise the mean itself would be NaN).

# %%
features_mean = np.nanmean(train_features, axis=0)

nan_indices = np.where(np.isnan(train_features))
train_features[nan_indices] = np.take(features_mean, nan_indices[1])

nan_indices = np.where(np.isnan(val_features))
val_features[nan_indices] = np.take(features_mean, nan_indices[1])

# %% [markdown]
# ## Normalize feature values
#
# Some numerical features take laerge integer values, so we should normalize them to a range more amenable to a neural network.

# %%
train_features -= features_mean
val_features -= features_mean

features_std = np.std(train_features, axis=0)
train_features /= features_std
val_features /= features_std

# %% [markdown]
# ## Normalize target values
#
# Since our targets also take very large integer values (dollar prices for houses), we should normalize them to a range more amenable to a neural network.
#
# Here, we chose median-normalization (divide by the median, without previously subtracting the mean): a price encoded as "1.5" means "50% higher than the median price", a price encoded as "0.5" is "50% of the median price", etc. This has the advantage of being easily interpretable by humans.

# %%
targets_median = np.median(train_targets, axis=0)
train_targets /= targets_median
val_targets /= targets_median

# %% [markdown]
# ## Train a wide-and-deep network

# %% [markdown]
# A wide and deep network consists of a deep network  (stack of `Dense` layers) and a wide network (single `Dense` layer) trained end to end. The final output is the sum of the predictions of each network. Often, the wide part and the deep part taken different features as inputs -- here, for simplicity, we feed all features to both networks.
#
# Since this is a regression problem, we don't apply any activation in our final layers, so as not to artificially constrain the range taken by the predictions.

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=features.shape[1:])
x = layers.Dense(128, activation='relu')(inputs)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.5)(x)
deep_output = layers.Dense(1)(x)

wide_output = layers.Dense(1)(inputs)
total_output = layers.add([deep_output, wide_output])

model = keras.Model(inputs, total_output, name='wide_and_deep')
model.summary()
# Out:
# Model: "wide_and_deep"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 183)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          23552       input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          16512       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            129         dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            184         input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1)            0           dense_3[0][0]
#                                                                  dense_4[0][0]
# ==================================================================================================
# Total params: 56,889
# Trainable params: 56,889
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Since this is a regression problem, we `MeanSquareError` (`mse`) as our loss. We also monitor `mean_absolute_percentage_error`, since this is a human-interpretable way to track performance on a price regression problem.

# %%
model.compile(optimizer='adam',
              loss='mse',
              metrics=['mean_absolute_percentage_error'])

callbacks = [keras.callbacks.ModelCheckpoint(
    'ames_regression_model_at_epoch_{epoch}.h5')]

model.fit(train_features, train_targets,
          batch_size=512,
          epochs=500,
          verbose=2,
          callbacks=callbacks,
          validation_data=(val_features, val_targets))
# Out:
# Train on 2344 samples, validate on 586 samples
# Epoch 1/500
# 2344/2344 - 1s - loss: 4.7667 - mean_absolute_percentage_error: 180.2890 - val_loss: 2.0175 - val_mean_absolute_percentage_error: 125.3691
# Epoch 2/500
# 2344/2344 - 0s - loss: 2.9648 - mean_absolute_percentage_error: 143.3357 - val_loss: 1.4821 - val_mean_absolute_percentage_error: 105.5913
# Epoch 3/500
# 2344/2344 - 0s - loss: 2.4766 - mean_absolute_percentage_error: 127.7989 - val_loss: 1.3212 - val_mean_absolute_percentage_error: 99.1847
# Epoch 4/500
# 2344/2344 - 0s - loss: 2.0363 - mean_absolute_percentage_error: 117.5641 - val_loss: 1.2346 - val_mean_absolute_percentage_error: 95.5825
# Epoch 5/500
# 2344/2344 - 0s - loss: 1.7519 - mean_absolute_percentage_error: 112.0753 - val_loss: 1.1310 - val_mean_absolute_percentage_error: 91.4418
# Epoch 6/500
# 2344/2344 - 0s - loss: 1.6732 - mean_absolute_percentage_error: 106.6928 - val_loss: 1.0821 - val_mean_absolute_percentage_error: 88.8964
# Epoch 7/500
# 2344/2344 - 0s - loss: 1.4949 - mean_absolute_percentage_error: 101.0293 - val_loss: 1.0875 - val_mean_absolute_percentage_error: 88.3330
# Epoch 8/500
# 2344/2344 - 0s - loss: 1.2798 - mean_absolute_percentage_error: 95.2612 - val_loss: 1.0732 - val_mean_absolute_percentage_error: 87.3207
# Epoch 9/500
# 2344/2344 - 0s - loss: 1.1852 - mean_absolute_percentage_error: 90.7650 - val_loss: 0.9909 - val_mean_absolute_percentage_error: 83.9542
# Epoch 10/500
# 2344/2344 - 0s - loss: 1.1266 - mean_absolute_percentage_error: 87.7653 - val_loss: 0.9128 - val_mean_absolute_percentage_error: 80.6096
# Epoch 11/500
# 2344/2344 - 0s - loss: 0.9966 - mean_absolute_percentage_error: 82.1537 - val_loss: 0.8583 - val_mean_absolute_percentage_error: 78.0115
# Epoch 12/500
# 2344/2344 - 0s - loss: 0.9064 - mean_absolute_percentage_error: 79.5387 - val_loss: 0.8262 - val_mean_absolute_percentage_error: 76.2909
# Epoch 13/500
# 2344/2344 - 0s - loss: 0.8902 - mean_absolute_percentage_error: 76.8784 - val_loss: 0.7935 - val_mean_absolute_percentage_error: 74.4598
# Epoch 14/500
# 2344/2344 - 0s - loss: 0.7989 - mean_absolute_percentage_error: 75.9511 - val_loss: 0.7567 - val_mean_absolute_percentage_error: 72.4923
# Epoch 15/500
# 2344/2344 - 0s - loss: 0.7380 - mean_absolute_percentage_error: 71.6129 - val_loss: 0.7225 - val_mean_absolute_percentage_error: 70.7253
# Epoch 16/500
# 2344/2344 - 0s - loss: 0.7292 - mean_absolute_percentage_error: 70.7610 - val_loss: 0.6906 - val_mean_absolute_percentage_error: 69.0838
# Epoch 17/500
# 2344/2344 - 0s - loss: 0.6514 - mean_absolute_percentage_error: 66.7799 - val_loss: 0.6592 - val_mean_absolute_percentage_error: 67.4643
# Epoch 18/500
# 2344/2344 - 0s - loss: 0.6393 - mean_absolute_percentage_error: 66.0421 - val_loss: 0.6382 - val_mean_absolute_percentage_error: 66.2604
# Epoch 19/500
# 2344/2344 - 0s - loss: 0.6021 - mean_absolute_percentage_error: 64.6696 - val_loss: 0.6184 - val_mean_absolute_percentage_error: 65.0743
# Epoch 20/500
# 2344/2344 - 0s - loss: 0.5508 - mean_absolute_percentage_error: 61.1831 - val_loss: 0.5907 - val_mean_absolute_percentage_error: 63.5518
# Epoch 21/500
# 2344/2344 - 0s - loss: 0.5219 - mean_absolute_percentage_error: 60.4254 - val_loss: 0.5606 - val_mean_absolute_percentage_error: 61.8083
# Epoch 22/500
# 2344/2344 - 0s - loss: 0.4891 - mean_absolute_percentage_error: 57.8671 - val_loss: 0.5518 - val_mean_absolute_percentage_error: 61.0948
# Epoch 23/500
# 2344/2344 - 0s - loss: 0.4485 - mean_absolute_percentage_error: 55.3511 - val_loss: 0.5439 - val_mean_absolute_percentage_error: 60.5418
# Epoch 24/500
# 2344/2344 - 0s - loss: 0.4380 - mean_absolute_percentage_error: 54.9669 - val_loss: 0.5313 - val_mean_absolute_percentage_error: 59.8808
# Epoch 25/500
# 2344/2344 - 0s - loss: 0.4103 - mean_absolute_percentage_error: 53.6477 - val_loss: 0.5081 - val_mean_absolute_percentage_error: 58.6157
# Epoch 26/500
# 2344/2344 - 0s - loss: 0.4339 - mean_absolute_percentage_error: 53.1562 - val_loss: 0.4850 - val_mean_absolute_percentage_error: 57.1522
# Epoch 27/500
# 2344/2344 - 0s - loss: 0.3879 - mean_absolute_percentage_error: 50.2238 - val_loss: 0.4630 - val_mean_absolute_percentage_error: 55.8284
# Epoch 28/500
# 2344/2344 - 0s - loss: 0.3869 - mean_absolute_percentage_error: 50.7566 - val_loss: 0.4595 - val_mean_absolute_percentage_error: 55.7645
# Epoch 29/500
# 2344/2344 - 0s - loss: 0.3475 - mean_absolute_percentage_error: 47.6183 - val_loss: 0.4576 - val_mean_absolute_percentage_error: 55.7529
# Epoch 30/500
# 2344/2344 - 0s - loss: 0.3364 - mean_absolute_percentage_error: 48.4732 - val_loss: 0.4458 - val_mean_absolute_percentage_error: 55.1194
# Epoch 31/500
# 2344/2344 - 0s - loss: 0.3136 - mean_absolute_percentage_error: 46.4157 - val_loss: 0.4293 - val_mean_absolute_percentage_error: 54.2224
# Epoch 32/500
# 2344/2344 - 0s - loss: 0.2986 - mean_absolute_percentage_error: 44.8768 - val_loss: 0.4060 - val_mean_absolute_percentage_error: 52.6807
# Epoch 33/500
# 2344/2344 - 0s - loss: 0.3000 - mean_absolute_percentage_error: 44.8553 - val_loss: 0.3997 - val_mean_absolute_percentage_error: 52.1695
# Epoch 34/500
# 2344/2344 - 0s - loss: 0.2848 - mean_absolute_percentage_error: 43.6483 - val_loss: 0.3966 - val_mean_absolute_percentage_error: 51.9330
# Epoch 35/500
# 2344/2344 - 0s - loss: 0.2729 - mean_absolute_percentage_error: 42.1044 - val_loss: 0.3913 - val_mean_absolute_percentage_error: 51.6767
# Epoch 36/500
# 2344/2344 - 0s - loss: 0.2640 - mean_absolute_percentage_error: 41.9199 - val_loss: 0.3864 - val_mean_absolute_percentage_error: 51.4208
# Epoch 37/500
# 2344/2344 - 0s - loss: 0.2525 - mean_absolute_percentage_error: 41.2181 - val_loss: 0.3786 - val_mean_absolute_percentage_error: 50.9049
# Epoch 38/500
# 2344/2344 - 0s - loss: 0.2463 - mean_absolute_percentage_error: 40.8260 - val_loss: 0.3645 - val_mean_absolute_percentage_error: 49.9285
# Epoch 39/500
# 2344/2344 - 0s - loss: 0.2327 - mean_absolute_percentage_error: 39.4543 - val_loss: 0.3521 - val_mean_absolute_percentage_error: 49.0207
# Epoch 40/500
# 2344/2344 - 0s - loss: 0.2350 - mean_absolute_percentage_error: 38.5060 - val_loss: 0.3517 - val_mean_absolute_percentage_error: 49.0705
# Epoch 41/500
# 2344/2344 - 0s - loss: 0.2223 - mean_absolute_percentage_error: 38.2196 - val_loss: 0.3521 - val_mean_absolute_percentage_error: 49.2802
# Epoch 42/500
# 2344/2344 - 0s - loss: 0.2132 - mean_absolute_percentage_error: 37.3941 - val_loss: 0.3370 - val_mean_absolute_percentage_error: 48.3214
# Epoch 43/500
# 2344/2344 - 0s - loss: 0.1967 - mean_absolute_percentage_error: 36.0757 - val_loss: 0.3291 - val_mean_absolute_percentage_error: 47.8190
# Epoch 44/500
# 2344/2344 - 0s - loss: 0.1978 - mean_absolute_percentage_error: 36.8594 - val_loss: 0.3234 - val_mean_absolute_percentage_error: 47.4334
# Epoch 45/500
# 2344/2344 - 0s - loss: 0.2076 - mean_absolute_percentage_error: 37.7521 - val_loss: 0.3231 - val_mean_absolute_percentage_error: 47.3715
# Epoch 46/500
# 2344/2344 - 0s - loss: 0.1945 - mean_absolute_percentage_error: 35.8334 - val_loss: 0.3216 - val_mean_absolute_percentage_error: 47.2064
# Epoch 47/500
# 2344/2344 - 0s - loss: 0.1789 - mean_absolute_percentage_error: 33.9002 - val_loss: 0.3124 - val_mean_absolute_percentage_error: 46.4011
# Epoch 48/500
# 2344/2344 - 0s - loss: 0.1816 - mean_absolute_percentage_error: 34.3429 - val_loss: 0.3030 - val_mean_absolute_percentage_error: 45.5352
# Epoch 49/500
# 2344/2344 - 0s - loss: 0.1641 - mean_absolute_percentage_error: 32.8047 - val_loss: 0.2901 - val_mean_absolute_percentage_error: 44.5036
# Epoch 50/500
# 2344/2344 - 0s - loss: 0.1593 - mean_absolute_percentage_error: 32.0488 - val_loss: 0.2842 - val_mean_absolute_percentage_error: 44.0506
# Epoch 51/500
# 2344/2344 - 0s - loss: 0.1653 - mean_absolute_percentage_error: 32.4272 - val_loss: 0.2887 - val_mean_absolute_percentage_error: 44.3999
# Epoch 52/500
# 2344/2344 - 0s - loss: 0.1603 - mean_absolute_percentage_error: 32.4500 - val_loss: 0.2838 - val_mean_absolute_percentage_error: 44.0113
# Epoch 53/500
# 2344/2344 - 0s - loss: 0.1551 - mean_absolute_percentage_error: 30.9218 - val_loss: 0.2749 - val_mean_absolute_percentage_error: 43.3158
# Epoch 54/500
# 2344/2344 - 0s - loss: 0.1503 - mean_absolute_percentage_error: 30.6417 - val_loss: 0.2677 - val_mean_absolute_percentage_error: 42.8859
# Epoch 55/500
# 2344/2344 - 0s - loss: 0.1531 - mean_absolute_percentage_error: 31.1337 - val_loss: 0.2766 - val_mean_absolute_percentage_error: 43.7476
# Epoch 56/500
# 2344/2344 - 0s - loss: 0.1518 - mean_absolute_percentage_error: 31.1972 - val_loss: 0.2755 - val_mean_absolute_percentage_error: 43.6617
# Epoch 57/500
# 2344/2344 - 0s - loss: 0.1417 - mean_absolute_percentage_error: 29.4650 - val_loss: 0.2674 - val_mean_absolute_percentage_error: 42.8606
# Epoch 58/500
# 2344/2344 - 0s - loss: 0.1413 - mean_absolute_percentage_error: 30.1934 - val_loss: 0.2524 - val_mean_absolute_percentage_error: 41.4379
# Epoch 59/500
# 2344/2344 - 0s - loss: 0.1371 - mean_absolute_percentage_error: 29.7291 - val_loss: 0.2489 - val_mean_absolute_percentage_error: 41.2435
# Epoch 60/500
# 2344/2344 - 0s - loss: 0.1337 - mean_absolute_percentage_error: 29.7744 - val_loss: 0.2508 - val_mean_absolute_percentage_error: 41.6228
# Epoch 61/500
# 2344/2344 - 0s - loss: 0.1269 - mean_absolute_percentage_error: 28.3328 - val_loss: 0.2507 - val_mean_absolute_percentage_error: 41.7551
# Epoch 62/500
# 2344/2344 - 0s - loss: 0.1389 - mean_absolute_percentage_error: 29.6032 - val_loss: 0.2470 - val_mean_absolute_percentage_error: 41.4175
# Epoch 63/500
# 2344/2344 - 0s - loss: 0.1319 - mean_absolute_percentage_error: 28.5703 - val_loss: 0.2447 - val_mean_absolute_percentage_error: 40.9995
# Epoch 64/500
# 2344/2344 - 0s - loss: 0.1228 - mean_absolute_percentage_error: 27.9878 - val_loss: 0.2414 - val_mean_absolute_percentage_error: 40.7756
# Epoch 65/500
# 2344/2344 - 0s - loss: 0.1129 - mean_absolute_percentage_error: 26.8469 - val_loss: 0.2322 - val_mean_absolute_percentage_error: 39.8301
# Epoch 66/500
# 2344/2344 - 0s - loss: 0.1235 - mean_absolute_percentage_error: 28.1755 - val_loss: 0.2244 - val_mean_absolute_percentage_error: 39.0193
# Epoch 67/500
# 2344/2344 - 0s - loss: 0.1155 - mean_absolute_percentage_error: 26.4485 - val_loss: 0.2199 - val_mean_absolute_percentage_error: 38.5455
# Epoch 68/500
# 2344/2344 - 0s - loss: 0.1171 - mean_absolute_percentage_error: 26.8562 - val_loss: 0.2165 - val_mean_absolute_percentage_error: 38.1943
# Epoch 69/500
# 2344/2344 - 0s - loss: 0.1106 - mean_absolute_percentage_error: 26.0126 - val_loss: 0.2187 - val_mean_absolute_percentage_error: 38.5332
# Epoch 70/500
# 2344/2344 - 0s - loss: 0.1166 - mean_absolute_percentage_error: 27.0837 - val_loss: 0.2097 - val_mean_absolute_percentage_error: 37.7547
# Epoch 71/500
# 2344/2344 - 0s - loss: 0.1076 - mean_absolute_percentage_error: 26.4308 - val_loss: 0.2034 - val_mean_absolute_percentage_error: 37.1100
# Epoch 72/500
# 2344/2344 - 0s - loss: 0.1076 - mean_absolute_percentage_error: 26.2516 - val_loss: 0.2053 - val_mean_absolute_percentage_error: 37.1667
# Epoch 73/500
# 2344/2344 - 0s - loss: 0.1014 - mean_absolute_percentage_error: 25.7608 - val_loss: 0.2035 - val_mean_absolute_percentage_error: 37.0422
# Epoch 74/500
# 2344/2344 - 0s - loss: 0.1020 - mean_absolute_percentage_error: 25.5174 - val_loss: 0.1999 - val_mean_absolute_percentage_error: 36.7747
# Epoch 75/500
# 2344/2344 - 0s - loss: 0.1012 - mean_absolute_percentage_error: 24.7039 - val_loss: 0.1937 - val_mean_absolute_percentage_error: 36.0696
# Epoch 76/500
# 2344/2344 - 0s - loss: 0.0968 - mean_absolute_percentage_error: 24.6286 - val_loss: 0.1903 - val_mean_absolute_percentage_error: 35.6688
# Epoch 77/500
# 2344/2344 - 0s - loss: 0.0951 - mean_absolute_percentage_error: 24.2359 - val_loss: 0.1846 - val_mean_absolute_percentage_error: 35.2225
# Epoch 78/500
# 2344/2344 - 0s - loss: 0.0997 - mean_absolute_percentage_error: 24.6145 - val_loss: 0.1824 - val_mean_absolute_percentage_error: 35.1783
# Epoch 79/500
# 2344/2344 - 0s - loss: 0.0926 - mean_absolute_percentage_error: 24.0559 - val_loss: 0.1787 - val_mean_absolute_percentage_error: 34.8581
# Epoch 80/500
# 2344/2344 - 0s - loss: 0.0910 - mean_absolute_percentage_error: 24.0040 - val_loss: 0.1761 - val_mean_absolute_percentage_error: 34.6345
# Epoch 81/500
# 2344/2344 - 0s - loss: 0.0946 - mean_absolute_percentage_error: 23.4780 - val_loss: 0.1765 - val_mean_absolute_percentage_error: 34.6419
# Epoch 82/500
# 2344/2344 - 0s - loss: 0.0914 - mean_absolute_percentage_error: 23.4444 - val_loss: 0.1691 - val_mean_absolute_percentage_error: 33.8751
# Epoch 83/500
# 2344/2344 - 0s - loss: 0.0917 - mean_absolute_percentage_error: 23.6053 - val_loss: 0.1634 - val_mean_absolute_percentage_error: 33.3163
# Epoch 84/500
# 2344/2344 - 0s - loss: 0.0883 - mean_absolute_percentage_error: 23.8580 - val_loss: 0.1649 - val_mean_absolute_percentage_error: 33.5832
# Epoch 85/500
# 2344/2344 - 0s - loss: 0.0826 - mean_absolute_percentage_error: 22.2659 - val_loss: 0.1662 - val_mean_absolute_percentage_error: 33.8753
# Epoch 86/500
# 2344/2344 - 0s - loss: 0.0822 - mean_absolute_percentage_error: 22.4359 - val_loss: 0.1644 - val_mean_absolute_percentage_error: 33.5543
# Epoch 87/500
# 2344/2344 - 0s - loss: 0.0816 - mean_absolute_percentage_error: 22.2438 - val_loss: 0.1597 - val_mean_absolute_percentage_error: 32.9867
# Epoch 88/500
# 2344/2344 - 0s - loss: 0.0856 - mean_absolute_percentage_error: 22.7453 - val_loss: 0.1551 - val_mean_absolute_percentage_error: 32.3685
# Epoch 89/500
# 2344/2344 - 0s - loss: 0.0861 - mean_absolute_percentage_error: 22.3571 - val_loss: 0.1532 - val_mean_absolute_percentage_error: 32.0620
# Epoch 90/500
# 2344/2344 - 0s - loss: 0.0797 - mean_absolute_percentage_error: 22.2585 - val_loss: 0.1527 - val_mean_absolute_percentage_error: 31.8751
# Epoch 91/500
# 2344/2344 - 0s - loss: 0.0771 - mean_absolute_percentage_error: 21.6557 - val_loss: 0.1522 - val_mean_absolute_percentage_error: 31.8209
# Epoch 92/500
# 2344/2344 - 0s - loss: 0.0745 - mean_absolute_percentage_error: 21.3957 - val_loss: 0.1484 - val_mean_absolute_percentage_error: 31.3260
# Epoch 93/500
# 2344/2344 - 0s - loss: 0.0775 - mean_absolute_percentage_error: 21.3799 - val_loss: 0.1435 - val_mean_absolute_percentage_error: 30.6972
# Epoch 94/500
# 2344/2344 - 0s - loss: 0.0764 - mean_absolute_percentage_error: 21.7601 - val_loss: 0.1408 - val_mean_absolute_percentage_error: 30.4732
# Epoch 95/500
# 2344/2344 - 0s - loss: 0.0771 - mean_absolute_percentage_error: 21.8894 - val_loss: 0.1409 - val_mean_absolute_percentage_error: 30.6257
# Epoch 96/500
# 2344/2344 - 0s - loss: 0.0702 - mean_absolute_percentage_error: 20.9446 - val_loss: 0.1411 - val_mean_absolute_percentage_error: 30.6416
# Epoch 97/500
# 2344/2344 - 0s - loss: 0.0729 - mean_absolute_percentage_error: 20.4175 - val_loss: 0.1400 - val_mean_absolute_percentage_error: 30.2162
# Epoch 98/500
# 2344/2344 - 0s - loss: 0.0737 - mean_absolute_percentage_error: 20.6857 - val_loss: 0.1366 - val_mean_absolute_percentage_error: 29.7267
# Epoch 99/500
# 2344/2344 - 0s - loss: 0.0694 - mean_absolute_percentage_error: 20.4037 - val_loss: 0.1338 - val_mean_absolute_percentage_error: 29.3297
# Epoch 100/500
# 2344/2344 - 0s - loss: 0.0733 - mean_absolute_percentage_error: 21.0522 - val_loss: 0.1331 - val_mean_absolute_percentage_error: 29.5418
# Epoch 101/500
# 2344/2344 - 0s - loss: 0.0681 - mean_absolute_percentage_error: 19.8596 - val_loss: 0.1310 - val_mean_absolute_percentage_error: 29.4383
# Epoch 102/500
# 2344/2344 - 0s - loss: 0.0687 - mean_absolute_percentage_error: 20.2590 - val_loss: 0.1313 - val_mean_absolute_percentage_error: 29.4803
# Epoch 103/500
# 2344/2344 - 0s - loss: 0.0678 - mean_absolute_percentage_error: 20.6253 - val_loss: 0.1280 - val_mean_absolute_percentage_error: 28.8808
# Epoch 104/500
# 2344/2344 - 0s - loss: 0.0675 - mean_absolute_percentage_error: 20.2301 - val_loss: 0.1240 - val_mean_absolute_percentage_error: 28.2590
# Epoch 105/500
# 2344/2344 - 0s - loss: 0.0627 - mean_absolute_percentage_error: 19.3331 - val_loss: 0.1203 - val_mean_absolute_percentage_error: 27.8709
# Epoch 106/500
# 2344/2344 - 0s - loss: 0.0623 - mean_absolute_percentage_error: 19.5887 - val_loss: 0.1177 - val_mean_absolute_percentage_error: 27.7168
# Epoch 107/500
# 2344/2344 - 0s - loss: 0.0627 - mean_absolute_percentage_error: 18.9431 - val_loss: 0.1171 - val_mean_absolute_percentage_error: 27.6399
# Epoch 108/500
# 2344/2344 - 0s - loss: 0.0636 - mean_absolute_percentage_error: 19.1913 - val_loss: 0.1188 - val_mean_absolute_percentage_error: 27.8801
# Epoch 109/500
# 2344/2344 - 0s - loss: 0.0646 - mean_absolute_percentage_error: 19.3817 - val_loss: 0.1201 - val_mean_absolute_percentage_error: 28.0405
# Epoch 110/500
# 2344/2344 - 0s - loss: 0.0629 - mean_absolute_percentage_error: 18.9753 - val_loss: 0.1179 - val_mean_absolute_percentage_error: 27.5580
# Epoch 111/500
# 2344/2344 - 0s - loss: 0.0622 - mean_absolute_percentage_error: 19.0952 - val_loss: 0.1131 - val_mean_absolute_percentage_error: 26.6377
# Epoch 112/500
# 2344/2344 - 0s - loss: 0.0583 - mean_absolute_percentage_error: 18.3421 - val_loss: 0.1058 - val_mean_absolute_percentage_error: 25.4779
# Epoch 113/500
# 2344/2344 - 0s - loss: 0.0590 - mean_absolute_percentage_error: 18.5383 - val_loss: 0.1040 - val_mean_absolute_percentage_error: 25.2478
# Epoch 114/500
# 2344/2344 - 0s - loss: 0.0612 - mean_absolute_percentage_error: 18.5036 - val_loss: 0.1071 - val_mean_absolute_percentage_error: 25.8835
# Epoch 115/500
# 2344/2344 - 0s - loss: 0.0560 - mean_absolute_percentage_error: 17.8836 - val_loss: 0.1066 - val_mean_absolute_percentage_error: 25.9890
# Epoch 116/500
# 2344/2344 - 0s - loss: 0.0573 - mean_absolute_percentage_error: 18.1402 - val_loss: 0.1024 - val_mean_absolute_percentage_error: 25.3012
# Epoch 117/500
# 2344/2344 - 0s - loss: 0.0601 - mean_absolute_percentage_error: 18.2030 - val_loss: 0.0978 - val_mean_absolute_percentage_error: 24.4898
# Epoch 118/500
# 2344/2344 - 0s - loss: 0.0596 - mean_absolute_percentage_error: 18.2828 - val_loss: 0.0960 - val_mean_absolute_percentage_error: 24.1029
# Epoch 119/500
# 2344/2344 - 0s - loss: 0.0571 - mean_absolute_percentage_error: 17.9899 - val_loss: 0.0969 - val_mean_absolute_percentage_error: 24.5238
# Epoch 120/500
# 2344/2344 - 0s - loss: 0.0571 - mean_absolute_percentage_error: 18.0825 - val_loss: 0.0973 - val_mean_absolute_percentage_error: 24.7764
# Epoch 121/500
# 2344/2344 - 0s - loss: 0.0564 - mean_absolute_percentage_error: 17.8454 - val_loss: 0.0956 - val_mean_absolute_percentage_error: 24.5181
# Epoch 122/500
# 2344/2344 - 0s - loss: 0.0543 - mean_absolute_percentage_error: 17.5352 - val_loss: 0.0933 - val_mean_absolute_percentage_error: 24.1290
# Epoch 123/500
# 2344/2344 - 0s - loss: 0.0572 - mean_absolute_percentage_error: 17.8337 - val_loss: 0.0912 - val_mean_absolute_percentage_error: 23.6444
# Epoch 124/500
# 2344/2344 - 0s - loss: 0.0520 - mean_absolute_percentage_error: 17.4595 - val_loss: 0.0913 - val_mean_absolute_percentage_error: 23.5078
# Epoch 125/500
# 2344/2344 - 0s - loss: 0.0524 - mean_absolute_percentage_error: 16.9351 - val_loss: 0.0905 - val_mean_absolute_percentage_error: 23.3029
# Epoch 126/500
# 2344/2344 - 0s - loss: 0.0544 - mean_absolute_percentage_error: 17.2565 - val_loss: 0.0882 - val_mean_absolute_percentage_error: 23.0364
# Epoch 127/500
# 2344/2344 - 0s - loss: 0.0524 - mean_absolute_percentage_error: 16.6392 - val_loss: 0.0864 - val_mean_absolute_percentage_error: 22.8548
# Epoch 128/500
# 2344/2344 - 0s - loss: 0.0530 - mean_absolute_percentage_error: 17.2784 - val_loss: 0.0878 - val_mean_absolute_percentage_error: 23.0973
# Epoch 129/500
# 2344/2344 - 0s - loss: 0.0509 - mean_absolute_percentage_error: 16.6855 - val_loss: 0.0874 - val_mean_absolute_percentage_error: 23.0380
# Epoch 130/500
# 2344/2344 - 0s - loss: 0.0515 - mean_absolute_percentage_error: 16.8278 - val_loss: 0.0860 - val_mean_absolute_percentage_error: 22.8512
# Epoch 131/500
# 2344/2344 - 0s - loss: 0.0506 - mean_absolute_percentage_error: 16.5091 - val_loss: 0.0855 - val_mean_absolute_percentage_error: 22.7912
# Epoch 132/500
# 2344/2344 - 0s - loss: 0.0495 - mean_absolute_percentage_error: 16.3959 - val_loss: 0.0813 - val_mean_absolute_percentage_error: 22.0849
# Epoch 133/500
# 2344/2344 - 0s - loss: 0.0500 - mean_absolute_percentage_error: 17.1597 - val_loss: 0.0824 - val_mean_absolute_percentage_error: 22.2557
# Epoch 134/500
# 2344/2344 - 0s - loss: 0.0492 - mean_absolute_percentage_error: 16.4993 - val_loss: 0.0848 - val_mean_absolute_percentage_error: 22.5847
# Epoch 135/500
# 2344/2344 - 0s - loss: 0.0495 - mean_absolute_percentage_error: 16.3985 - val_loss: 0.0859 - val_mean_absolute_percentage_error: 22.7666
# Epoch 136/500
# 2344/2344 - 0s - loss: 0.0481 - mean_absolute_percentage_error: 16.0000 - val_loss: 0.0851 - val_mean_absolute_percentage_error: 22.5293
# Epoch 137/500
# 2344/2344 - 0s - loss: 0.0508 - mean_absolute_percentage_error: 16.5160 - val_loss: 0.0802 - val_mean_absolute_percentage_error: 21.7438
# Epoch 138/500
# 2344/2344 - 0s - loss: 0.0512 - mean_absolute_percentage_error: 16.8062 - val_loss: 0.0789 - val_mean_absolute_percentage_error: 21.5379
# Epoch 139/500
# 2344/2344 - 0s - loss: 0.0482 - mean_absolute_percentage_error: 16.2235 - val_loss: 0.0798 - val_mean_absolute_percentage_error: 21.7040
# Epoch 140/500
# 2344/2344 - 0s - loss: 0.0476 - mean_absolute_percentage_error: 16.0437 - val_loss: 0.0815 - val_mean_absolute_percentage_error: 22.0457
# Epoch 141/500
# 2344/2344 - 0s - loss: 0.0471 - mean_absolute_percentage_error: 15.7048 - val_loss: 0.0771 - val_mean_absolute_percentage_error: 21.3479
# Epoch 142/500
# 2344/2344 - 0s - loss: 0.0477 - mean_absolute_percentage_error: 15.7615 - val_loss: 0.0763 - val_mean_absolute_percentage_error: 21.3219
# Epoch 143/500
# 2344/2344 - 0s - loss: 0.0455 - mean_absolute_percentage_error: 15.7472 - val_loss: 0.0771 - val_mean_absolute_percentage_error: 21.4907
# Epoch 144/500
# 2344/2344 - 0s - loss: 0.0480 - mean_absolute_percentage_error: 15.7578 - val_loss: 0.0755 - val_mean_absolute_percentage_error: 21.2033
# Epoch 145/500
# 2344/2344 - 0s - loss: 0.0459 - mean_absolute_percentage_error: 15.5884 - val_loss: 0.0745 - val_mean_absolute_percentage_error: 20.9918
# Epoch 146/500
# 2344/2344 - 0s - loss: 0.0463 - mean_absolute_percentage_error: 15.6031 - val_loss: 0.0736 - val_mean_absolute_percentage_error: 20.8711
# Epoch 147/500
# 2344/2344 - 0s - loss: 0.0430 - mean_absolute_percentage_error: 15.3400 - val_loss: 0.0723 - val_mean_absolute_percentage_error: 20.7110
# Epoch 148/500
# 2344/2344 - 0s - loss: 0.0460 - mean_absolute_percentage_error: 15.5150 - val_loss: 0.0701 - val_mean_absolute_percentage_error: 20.3995
# Epoch 149/500
# 2344/2344 - 0s - loss: 0.0450 - mean_absolute_percentage_error: 15.6939 - val_loss: 0.0713 - val_mean_absolute_percentage_error: 20.3797
# Epoch 150/500
# 2344/2344 - 0s - loss: 0.0444 - mean_absolute_percentage_error: 15.3279 - val_loss: 0.0696 - val_mean_absolute_percentage_error: 20.0282
# Epoch 151/500
# 2344/2344 - 0s - loss: 0.0448 - mean_absolute_percentage_error: 15.3853 - val_loss: 0.0685 - val_mean_absolute_percentage_error: 19.9384
# Epoch 152/500
# 2344/2344 - 0s - loss: 0.0448 - mean_absolute_percentage_error: 15.2480 - val_loss: 0.0689 - val_mean_absolute_percentage_error: 19.9147
# Epoch 153/500
# 2344/2344 - 0s - loss: 0.0419 - mean_absolute_percentage_error: 15.1944 - val_loss: 0.0685 - val_mean_absolute_percentage_error: 19.9169
# Epoch 154/500
# 2344/2344 - 0s - loss: 0.0418 - mean_absolute_percentage_error: 15.0327 - val_loss: 0.0671 - val_mean_absolute_percentage_error: 19.7159
# Epoch 155/500
# 2344/2344 - 0s - loss: 0.0420 - mean_absolute_percentage_error: 14.8998 - val_loss: 0.0646 - val_mean_absolute_percentage_error: 19.2945
# Epoch 156/500
# 2344/2344 - 0s - loss: 0.0447 - mean_absolute_percentage_error: 15.6224 - val_loss: 0.0651 - val_mean_absolute_percentage_error: 19.3291
# Epoch 157/500
# 2344/2344 - 0s - loss: 0.0391 - mean_absolute_percentage_error: 14.1611 - val_loss: 0.0637 - val_mean_absolute_percentage_error: 19.0168
# Epoch 158/500
# 2344/2344 - 0s - loss: 0.0439 - mean_absolute_percentage_error: 14.7998 - val_loss: 0.0623 - val_mean_absolute_percentage_error: 18.6724
# Epoch 159/500
# 2344/2344 - 0s - loss: 0.0426 - mean_absolute_percentage_error: 14.9476 - val_loss: 0.0628 - val_mean_absolute_percentage_error: 18.8510
# Epoch 160/500
# 2344/2344 - 0s - loss: 0.0412 - mean_absolute_percentage_error: 14.3814 - val_loss: 0.0648 - val_mean_absolute_percentage_error: 19.4007
# Epoch 161/500
# 2344/2344 - 0s - loss: 0.0431 - mean_absolute_percentage_error: 14.8364 - val_loss: 0.0634 - val_mean_absolute_percentage_error: 19.0532
# Epoch 162/500
# 2344/2344 - 0s - loss: 0.0409 - mean_absolute_percentage_error: 14.6198 - val_loss: 0.0596 - val_mean_absolute_percentage_error: 18.2688
# Epoch 163/500
# 2344/2344 - 0s - loss: 0.0405 - mean_absolute_percentage_error: 14.4940 - val_loss: 0.0610 - val_mean_absolute_percentage_error: 18.6336
# Epoch 164/500
# 2344/2344 - 0s - loss: 0.0394 - mean_absolute_percentage_error: 14.2851 - val_loss: 0.0617 - val_mean_absolute_percentage_error: 18.8226
# Epoch 165/500
# 2344/2344 - 0s - loss: 0.0390 - mean_absolute_percentage_error: 14.2542 - val_loss: 0.0594 - val_mean_absolute_percentage_error: 18.3131
# Epoch 166/500
# 2344/2344 - 0s - loss: 0.0401 - mean_absolute_percentage_error: 14.3683 - val_loss: 0.0567 - val_mean_absolute_percentage_error: 17.7114
# Epoch 167/500
# 2344/2344 - 0s - loss: 0.0394 - mean_absolute_percentage_error: 14.3379 - val_loss: 0.0555 - val_mean_absolute_percentage_error: 17.4093
# Epoch 168/500
# 2344/2344 - 0s - loss: 0.0409 - mean_absolute_percentage_error: 14.4884 - val_loss: 0.0563 - val_mean_absolute_percentage_error: 17.7204
# Epoch 169/500
# 2344/2344 - 0s - loss: 0.0386 - mean_absolute_percentage_error: 14.1138 - val_loss: 0.0574 - val_mean_absolute_percentage_error: 17.9206
# Epoch 170/500
# 2344/2344 - 0s - loss: 0.0377 - mean_absolute_percentage_error: 13.7843 - val_loss: 0.0556 - val_mean_absolute_percentage_error: 17.4365
# Epoch 171/500
# 2344/2344 - 0s - loss: 0.0376 - mean_absolute_percentage_error: 13.8188 - val_loss: 0.0548 - val_mean_absolute_percentage_error: 17.3648
# Epoch 172/500
# 2344/2344 - 0s - loss: 0.0390 - mean_absolute_percentage_error: 13.8994 - val_loss: 0.0543 - val_mean_absolute_percentage_error: 17.3915
# Epoch 173/500
# 2344/2344 - 0s - loss: 0.0373 - mean_absolute_percentage_error: 13.7879 - val_loss: 0.0542 - val_mean_absolute_percentage_error: 17.3445
# Epoch 174/500
# 2344/2344 - 0s - loss: 0.0406 - mean_absolute_percentage_error: 13.8669 - val_loss: 0.0559 - val_mean_absolute_percentage_error: 17.6342
# Epoch 175/500
# 2344/2344 - 0s - loss: 0.0370 - mean_absolute_percentage_error: 13.6260 - val_loss: 0.0540 - val_mean_absolute_percentage_error: 17.2290
# Epoch 176/500
# 2344/2344 - 0s - loss: 0.0373 - mean_absolute_percentage_error: 13.6987 - val_loss: 0.0530 - val_mean_absolute_percentage_error: 16.8622
# Epoch 177/500
# 2344/2344 - 0s - loss: 0.0380 - mean_absolute_percentage_error: 13.8632 - val_loss: 0.0529 - val_mean_absolute_percentage_error: 16.8334
# Epoch 178/500
# 2344/2344 - 0s - loss: 0.0367 - mean_absolute_percentage_error: 13.5423 - val_loss: 0.0529 - val_mean_absolute_percentage_error: 17.0013
# Epoch 179/500
# 2344/2344 - 0s - loss: 0.0379 - mean_absolute_percentage_error: 13.6525 - val_loss: 0.0536 - val_mean_absolute_percentage_error: 17.1720
# Epoch 180/500
# 2344/2344 - 0s - loss: 0.0362 - mean_absolute_percentage_error: 13.5423 - val_loss: 0.0515 - val_mean_absolute_percentage_error: 16.6348
# Epoch 181/500
# 2344/2344 - 0s - loss: 0.0355 - mean_absolute_percentage_error: 13.4235 - val_loss: 0.0496 - val_mean_absolute_percentage_error: 16.0378
# Epoch 182/500
# 2344/2344 - 0s - loss: 0.0342 - mean_absolute_percentage_error: 13.2856 - val_loss: 0.0514 - val_mean_absolute_percentage_error: 16.4317
# Epoch 183/500
# 2344/2344 - 0s - loss: 0.0358 - mean_absolute_percentage_error: 13.2106 - val_loss: 0.0516 - val_mean_absolute_percentage_error: 16.4409
# Epoch 184/500
# 2344/2344 - 0s - loss: 0.0359 - mean_absolute_percentage_error: 13.2293 - val_loss: 0.0490 - val_mean_absolute_percentage_error: 16.1228
# Epoch 185/500
# 2344/2344 - 0s - loss: 0.0359 - mean_absolute_percentage_error: 13.2442 - val_loss: 0.0480 - val_mean_absolute_percentage_error: 16.0140
# Epoch 186/500
# 2344/2344 - 0s - loss: 0.0362 - mean_absolute_percentage_error: 13.4305 - val_loss: 0.0483 - val_mean_absolute_percentage_error: 16.0507
# Epoch 187/500
# 2344/2344 - 0s - loss: 0.0352 - mean_absolute_percentage_error: 13.4069 - val_loss: 0.0479 - val_mean_absolute_percentage_error: 15.7985
# Epoch 188/500
# 2344/2344 - 0s - loss: 0.0355 - mean_absolute_percentage_error: 13.4480 - val_loss: 0.0473 - val_mean_absolute_percentage_error: 15.5783
# Epoch 189/500
# 2344/2344 - 0s - loss: 0.0363 - mean_absolute_percentage_error: 13.3792 - val_loss: 0.0477 - val_mean_absolute_percentage_error: 15.5850
# Epoch 190/500
# 2344/2344 - 0s - loss: 0.0349 - mean_absolute_percentage_error: 13.1515 - val_loss: 0.0478 - val_mean_absolute_percentage_error: 15.7668
# Epoch 191/500
# 2344/2344 - 0s - loss: 0.0330 - mean_absolute_percentage_error: 12.9411 - val_loss: 0.0476 - val_mean_absolute_percentage_error: 15.8836
# Epoch 192/500
# 2344/2344 - 0s - loss: 0.0347 - mean_absolute_percentage_error: 13.0874 - val_loss: 0.0478 - val_mean_absolute_percentage_error: 16.0107
# Epoch 193/500
# 2344/2344 - 0s - loss: 0.0356 - mean_absolute_percentage_error: 13.1402 - val_loss: 0.0484 - val_mean_absolute_percentage_error: 15.9573
# Epoch 194/500
# 2344/2344 - 0s - loss: 0.0349 - mean_absolute_percentage_error: 12.8773 - val_loss: 0.0479 - val_mean_absolute_percentage_error: 15.6413
# Epoch 195/500
# 2344/2344 - 0s - loss: 0.0358 - mean_absolute_percentage_error: 12.8927 - val_loss: 0.0460 - val_mean_absolute_percentage_error: 15.2488
# Epoch 196/500
# 2344/2344 - 0s - loss: 0.0330 - mean_absolute_percentage_error: 12.6208 - val_loss: 0.0454 - val_mean_absolute_percentage_error: 15.2289
# Epoch 197/500
# 2344/2344 - 0s - loss: 0.0347 - mean_absolute_percentage_error: 12.6335 - val_loss: 0.0458 - val_mean_absolute_percentage_error: 15.2765
# Epoch 198/500
# 2344/2344 - 0s - loss: 0.0364 - mean_absolute_percentage_error: 12.9861 - val_loss: 0.0463 - val_mean_absolute_percentage_error: 15.4666
# Epoch 199/500
# 2344/2344 - 0s - loss: 0.0337 - mean_absolute_percentage_error: 12.8096 - val_loss: 0.0463 - val_mean_absolute_percentage_error: 15.3810
# Epoch 200/500
# 2344/2344 - 0s - loss: 0.0330 - mean_absolute_percentage_error: 12.6793 - val_loss: 0.0453 - val_mean_absolute_percentage_error: 15.0435
# Epoch 201/500
# 2344/2344 - 0s - loss: 0.0343 - mean_absolute_percentage_error: 12.7971 - val_loss: 0.0432 - val_mean_absolute_percentage_error: 14.6411
# Epoch 202/500
# 2344/2344 - 0s - loss: 0.0343 - mean_absolute_percentage_error: 12.7296 - val_loss: 0.0442 - val_mean_absolute_percentage_error: 14.8955
# Epoch 203/500
# 2344/2344 - 0s - loss: 0.0334 - mean_absolute_percentage_error: 12.5569 - val_loss: 0.0445 - val_mean_absolute_percentage_error: 15.2246
# Epoch 204/500
# 2344/2344 - 0s - loss: 0.0325 - mean_absolute_percentage_error: 12.8813 - val_loss: 0.0438 - val_mean_absolute_percentage_error: 15.1052
# Epoch 205/500
# 2344/2344 - 0s - loss: 0.0336 - mean_absolute_percentage_error: 12.6037 - val_loss: 0.0418 - val_mean_absolute_percentage_error: 14.5640
# Epoch 206/500
# 2344/2344 - 0s - loss: 0.0347 - mean_absolute_percentage_error: 12.7030 - val_loss: 0.0429 - val_mean_absolute_percentage_error: 14.6324
# Epoch 207/500
# 2344/2344 - 0s - loss: 0.0304 - mean_absolute_percentage_error: 12.2871 - val_loss: 0.0434 - val_mean_absolute_percentage_error: 14.6992
# Epoch 208/500
# 2344/2344 - 0s - loss: 0.0331 - mean_absolute_percentage_error: 12.2005 - val_loss: 0.0428 - val_mean_absolute_percentage_error: 14.7296
# Epoch 209/500
# 2344/2344 - 0s - loss: 0.0314 - mean_absolute_percentage_error: 12.0323 - val_loss: 0.0414 - val_mean_absolute_percentage_error: 14.5746
# Epoch 210/500
# 2344/2344 - 0s - loss: 0.0330 - mean_absolute_percentage_error: 12.2885 - val_loss: 0.0416 - val_mean_absolute_percentage_error: 14.6104
# Epoch 211/500
# 2344/2344 - 0s - loss: 0.0315 - mean_absolute_percentage_error: 12.3066 - val_loss: 0.0401 - val_mean_absolute_percentage_error: 14.3393
# Epoch 212/500
# 2344/2344 - 0s - loss: 0.0306 - mean_absolute_percentage_error: 11.9453 - val_loss: 0.0400 - val_mean_absolute_percentage_error: 14.1381
# Epoch 213/500
# 2344/2344 - 0s - loss: 0.0326 - mean_absolute_percentage_error: 12.1469 - val_loss: 0.0393 - val_mean_absolute_percentage_error: 14.0607
# Epoch 214/500
# 2344/2344 - 0s - loss: 0.0312 - mean_absolute_percentage_error: 12.2007 - val_loss: 0.0414 - val_mean_absolute_percentage_error: 14.3504
# Epoch 215/500
# 2344/2344 - 0s - loss: 0.0327 - mean_absolute_percentage_error: 12.3993 - val_loss: 0.0415 - val_mean_absolute_percentage_error: 14.4176
# Epoch 216/500
# 2344/2344 - 0s - loss: 0.0318 - mean_absolute_percentage_error: 12.1614 - val_loss: 0.0408 - val_mean_absolute_percentage_error: 14.2341
# Epoch 217/500
# 2344/2344 - 0s - loss: 0.0302 - mean_absolute_percentage_error: 12.1285 - val_loss: 0.0408 - val_mean_absolute_percentage_error: 14.2255
# Epoch 218/500
# 2344/2344 - 0s - loss: 0.0297 - mean_absolute_percentage_error: 11.7036 - val_loss: 0.0406 - val_mean_absolute_percentage_error: 14.1276
# Epoch 219/500
# 2344/2344 - 0s - loss: 0.0322 - mean_absolute_percentage_error: 12.2516 - val_loss: 0.0391 - val_mean_absolute_percentage_error: 13.8853
# Epoch 220/500
# 2344/2344 - 0s - loss: 0.0306 - mean_absolute_percentage_error: 11.9540 - val_loss: 0.0377 - val_mean_absolute_percentage_error: 13.5203
# Epoch 221/500
# 2344/2344 - 0s - loss: 0.0314 - mean_absolute_percentage_error: 11.8309 - val_loss: 0.0375 - val_mean_absolute_percentage_error: 13.5186
# Epoch 222/500
# 2344/2344 - 0s - loss: 0.0295 - mean_absolute_percentage_error: 11.7490 - val_loss: 0.0373 - val_mean_absolute_percentage_error: 13.5911
# Epoch 223/500
# 2344/2344 - 0s - loss: 0.0320 - mean_absolute_percentage_error: 12.1016 - val_loss: 0.0380 - val_mean_absolute_percentage_error: 13.7920
# Epoch 224/500
# 2344/2344 - 0s - loss: 0.0314 - mean_absolute_percentage_error: 11.9213 - val_loss: 0.0376 - val_mean_absolute_percentage_error: 13.6975
# Epoch 225/500
# 2344/2344 - 0s - loss: 0.0309 - mean_absolute_percentage_error: 11.9983 - val_loss: 0.0370 - val_mean_absolute_percentage_error: 13.3539
# Epoch 226/500
# 2344/2344 - 0s - loss: 0.0308 - mean_absolute_percentage_error: 11.6281 - val_loss: 0.0363 - val_mean_absolute_percentage_error: 13.1085
# Epoch 227/500
# 2344/2344 - 0s - loss: 0.0288 - mean_absolute_percentage_error: 11.6363 - val_loss: 0.0368 - val_mean_absolute_percentage_error: 13.2707
# Epoch 228/500
# 2344/2344 - 0s - loss: 0.0298 - mean_absolute_percentage_error: 12.0744 - val_loss: 0.0377 - val_mean_absolute_percentage_error: 13.6820
# Epoch 229/500
# 2344/2344 - 0s - loss: 0.0302 - mean_absolute_percentage_error: 11.5814 - val_loss: 0.0373 - val_mean_absolute_percentage_error: 13.5654
# Epoch 230/500
# 2344/2344 - 0s - loss: 0.0305 - mean_absolute_percentage_error: 11.8794 - val_loss: 0.0368 - val_mean_absolute_percentage_error: 13.4659
# Epoch 231/500
# 2344/2344 - 0s - loss: 0.0304 - mean_absolute_percentage_error: 11.8111 - val_loss: 0.0363 - val_mean_absolute_percentage_error: 13.2544
# Epoch 232/500
# 2344/2344 - 0s - loss: 0.0305 - mean_absolute_percentage_error: 11.6427 - val_loss: 0.0357 - val_mean_absolute_percentage_error: 13.0354
# Epoch 233/500
# 2344/2344 - 0s - loss: 0.0292 - mean_absolute_percentage_error: 11.5229 - val_loss: 0.0352 - val_mean_absolute_percentage_error: 12.9008
# Epoch 234/500
# 2344/2344 - 0s - loss: 0.0287 - mean_absolute_percentage_error: 11.5591 - val_loss: 0.0359 - val_mean_absolute_percentage_error: 13.1923
# Epoch 235/500
# 2344/2344 - 0s - loss: 0.0295 - mean_absolute_percentage_error: 11.4098 - val_loss: 0.0355 - val_mean_absolute_percentage_error: 13.1345
# Epoch 236/500
# 2344/2344 - 0s - loss: 0.0283 - mean_absolute_percentage_error: 11.5956 - val_loss: 0.0354 - val_mean_absolute_percentage_error: 13.1520
# Epoch 237/500
# 2344/2344 - 0s - loss: 0.0297 - mean_absolute_percentage_error: 11.3679 - val_loss: 0.0368 - val_mean_absolute_percentage_error: 13.2537
# Epoch 238/500
# 2344/2344 - 0s - loss: 0.0295 - mean_absolute_percentage_error: 11.3285 - val_loss: 0.0360 - val_mean_absolute_percentage_error: 12.8933
# Epoch 239/500
# 2344/2344 - 0s - loss: 0.0303 - mean_absolute_percentage_error: 11.6930 - val_loss: 0.0351 - val_mean_absolute_percentage_error: 12.9259
# Epoch 240/500
# 2344/2344 - 0s - loss: 0.0300 - mean_absolute_percentage_error: 11.5946 - val_loss: 0.0352 - val_mean_absolute_percentage_error: 13.1107
# Epoch 241/500
# 2344/2344 - 0s - loss: 0.0301 - mean_absolute_percentage_error: 11.5881 - val_loss: 0.0348 - val_mean_absolute_percentage_error: 12.9071
# Epoch 242/500
# 2344/2344 - 0s - loss: 0.0276 - mean_absolute_percentage_error: 11.1122 - val_loss: 0.0341 - val_mean_absolute_percentage_error: 12.7743
# Epoch 243/500
# 2344/2344 - 0s - loss: 0.0289 - mean_absolute_percentage_error: 11.5698 - val_loss: 0.0348 - val_mean_absolute_percentage_error: 12.8738
# Epoch 244/500
# 2344/2344 - 0s - loss: 0.0299 - mean_absolute_percentage_error: 11.2430 - val_loss: 0.0349 - val_mean_absolute_percentage_error: 12.9507
# Epoch 245/500
# 2344/2344 - 0s - loss: 0.0286 - mean_absolute_percentage_error: 11.2600 - val_loss: 0.0333 - val_mean_absolute_percentage_error: 12.5989
# Epoch 246/500
# 2344/2344 - 0s - loss: 0.0291 - mean_absolute_percentage_error: 11.1771 - val_loss: 0.0335 - val_mean_absolute_percentage_error: 12.5472
# Epoch 247/500
# 2344/2344 - 0s - loss: 0.0276 - mean_absolute_percentage_error: 11.0137 - val_loss: 0.0334 - val_mean_absolute_percentage_error: 12.4853
# Epoch 248/500
# 2344/2344 - 0s - loss: 0.0270 - mean_absolute_percentage_error: 10.9412 - val_loss: 0.0346 - val_mean_absolute_percentage_error: 12.7304
# Epoch 249/500
# 2344/2344 - 0s - loss: 0.0283 - mean_absolute_percentage_error: 11.1031 - val_loss: 0.0339 - val_mean_absolute_percentage_error: 12.7617
# Epoch 250/500
# 2344/2344 - 0s - loss: 0.0279 - mean_absolute_percentage_error: 10.8750 - val_loss: 0.0324 - val_mean_absolute_percentage_error: 12.4941
# Epoch 251/500
# 2344/2344 - 0s - loss: 0.0277 - mean_absolute_percentage_error: 11.0492 - val_loss: 0.0316 - val_mean_absolute_percentage_error: 12.0552
# Epoch 252/500
# 2344/2344 - 0s - loss: 0.0291 - mean_absolute_percentage_error: 11.3039 - val_loss: 0.0334 - val_mean_absolute_percentage_error: 12.2578
# Epoch 253/500
# 2344/2344 - 0s - loss: 0.0272 - mean_absolute_percentage_error: 11.0775 - val_loss: 0.0335 - val_mean_absolute_percentage_error: 12.4606
# Epoch 254/500
# 2344/2344 - 0s - loss: 0.0265 - mean_absolute_percentage_error: 11.0995 - val_loss: 0.0326 - val_mean_absolute_percentage_error: 12.2959
# Epoch 255/500
# 2344/2344 - 0s - loss: 0.0274 - mean_absolute_percentage_error: 11.0332 - val_loss: 0.0318 - val_mean_absolute_percentage_error: 12.2105
# Epoch 256/500
# 2344/2344 - 0s - loss: 0.0275 - mean_absolute_percentage_error: 11.0599 - val_loss: 0.0319 - val_mean_absolute_percentage_error: 12.1850
# Epoch 257/500
# 2344/2344 - 0s - loss: 0.0262 - mean_absolute_percentage_error: 11.0900 - val_loss: 0.0320 - val_mean_absolute_percentage_error: 12.1892
# Epoch 258/500
# 2344/2344 - 0s - loss: 0.0280 - mean_absolute_percentage_error: 10.8386 - val_loss: 0.0319 - val_mean_absolute_percentage_error: 12.3517
# Epoch 259/500
# 2344/2344 - 0s - loss: 0.0269 - mean_absolute_percentage_error: 11.1347 - val_loss: 0.0318 - val_mean_absolute_percentage_error: 12.4030
# Epoch 260/500
# 2344/2344 - 0s - loss: 0.0277 - mean_absolute_percentage_error: 10.7850 - val_loss: 0.0309 - val_mean_absolute_percentage_error: 11.9705
# Epoch 261/500
# 2344/2344 - 0s - loss: 0.0266 - mean_absolute_percentage_error: 10.8381 - val_loss: 0.0304 - val_mean_absolute_percentage_error: 11.8631
# Epoch 262/500
# 2344/2344 - 0s - loss: 0.0273 - mean_absolute_percentage_error: 10.9726 - val_loss: 0.0309 - val_mean_absolute_percentage_error: 12.2007
# Epoch 263/500
# 2344/2344 - 0s - loss: 0.0275 - mean_absolute_percentage_error: 10.9116 - val_loss: 0.0313 - val_mean_absolute_percentage_error: 12.2708
# Epoch 264/500
# 2344/2344 - 0s - loss: 0.0274 - mean_absolute_percentage_error: 10.9001 - val_loss: 0.0309 - val_mean_absolute_percentage_error: 12.0365
# Epoch 265/500
# 2344/2344 - 0s - loss: 0.0268 - mean_absolute_percentage_error: 10.7529 - val_loss: 0.0301 - val_mean_absolute_percentage_error: 11.7803
# Epoch 266/500
# 2344/2344 - 0s - loss: 0.0271 - mean_absolute_percentage_error: 10.8157 - val_loss: 0.0301 - val_mean_absolute_percentage_error: 11.6744
# Epoch 267/500
# 2344/2344 - 0s - loss: 0.0266 - mean_absolute_percentage_error: 10.8145 - val_loss: 0.0301 - val_mean_absolute_percentage_error: 11.6884
# Epoch 268/500
# 2344/2344 - 0s - loss: 0.0261 - mean_absolute_percentage_error: 10.6730 - val_loss: 0.0308 - val_mean_absolute_percentage_error: 11.8891
# Epoch 269/500
# 2344/2344 - 0s - loss: 0.0264 - mean_absolute_percentage_error: 10.6761 - val_loss: 0.0306 - val_mean_absolute_percentage_error: 11.8631
# Epoch 270/500
# 2344/2344 - 0s - loss: 0.0249 - mean_absolute_percentage_error: 10.5486 - val_loss: 0.0303 - val_mean_absolute_percentage_error: 11.7449
# Epoch 271/500
# 2344/2344 - 0s - loss: 0.0268 - mean_absolute_percentage_error: 10.7357 - val_loss: 0.0295 - val_mean_absolute_percentage_error: 11.6668
# Epoch 272/500
# 2344/2344 - 0s - loss: 0.0263 - mean_absolute_percentage_error: 10.5086 - val_loss: 0.0288 - val_mean_absolute_percentage_error: 11.6743
# Epoch 273/500
# 2344/2344 - 0s - loss: 0.0259 - mean_absolute_percentage_error: 10.6211 - val_loss: 0.0296 - val_mean_absolute_percentage_error: 11.8144
# Epoch 274/500
# 2344/2344 - 0s - loss: 0.0270 - mean_absolute_percentage_error: 10.4591 - val_loss: 0.0293 - val_mean_absolute_percentage_error: 11.6721
# Epoch 275/500
# 2344/2344 - 0s - loss: 0.0263 - mean_absolute_percentage_error: 10.5529 - val_loss: 0.0279 - val_mean_absolute_percentage_error: 11.3184
# Epoch 276/500
# 2344/2344 - 0s - loss: 0.0250 - mean_absolute_percentage_error: 10.5749 - val_loss: 0.0278 - val_mean_absolute_percentage_error: 11.4331
# Epoch 277/500
# 2344/2344 - 0s - loss: 0.0261 - mean_absolute_percentage_error: 10.5340 - val_loss: 0.0288 - val_mean_absolute_percentage_error: 11.8929
# Epoch 278/500
# 2344/2344 - 0s - loss: 0.0276 - mean_absolute_percentage_error: 10.8716 - val_loss: 0.0285 - val_mean_absolute_percentage_error: 11.7004
# Epoch 279/500
# 2344/2344 - 0s - loss: 0.0255 - mean_absolute_percentage_error: 10.5669 - val_loss: 0.0283 - val_mean_absolute_percentage_error: 11.4668
# Epoch 280/500
# 2344/2344 - 0s - loss: 0.0261 - mean_absolute_percentage_error: 10.4139 - val_loss: 0.0275 - val_mean_absolute_percentage_error: 11.2316
# Epoch 281/500
# 2344/2344 - 0s - loss: 0.0270 - mean_absolute_percentage_error: 10.5653 - val_loss: 0.0275 - val_mean_absolute_percentage_error: 11.3257
# Epoch 282/500
# 2344/2344 - 0s - loss: 0.0251 - mean_absolute_percentage_error: 10.6577 - val_loss: 0.0283 - val_mean_absolute_percentage_error: 11.6081
# Epoch 283/500
# 2344/2344 - 0s - loss: 0.0260 - mean_absolute_percentage_error: 10.5525 - val_loss: 0.0276 - val_mean_absolute_percentage_error: 11.3347
# Epoch 284/500
# 2344/2344 - 0s - loss: 0.0260 - mean_absolute_percentage_error: 10.3165 - val_loss: 0.0270 - val_mean_absolute_percentage_error: 11.0566
# Epoch 285/500
# 2344/2344 - 0s - loss: 0.0239 - mean_absolute_percentage_error: 10.5650 - val_loss: 0.0271 - val_mean_absolute_percentage_error: 11.0339
# Epoch 286/500
# 2344/2344 - 0s - loss: 0.0259 - mean_absolute_percentage_error: 10.3645 - val_loss: 0.0280 - val_mean_absolute_percentage_error: 11.2771
# Epoch 287/500
# 2344/2344 - 0s - loss: 0.0238 - mean_absolute_percentage_error: 10.3137 - val_loss: 0.0278 - val_mean_absolute_percentage_error: 11.4620
# Epoch 288/500
# 2344/2344 - 0s - loss: 0.0246 - mean_absolute_percentage_error: 10.5000 - val_loss: 0.0272 - val_mean_absolute_percentage_error: 11.3769
# Epoch 289/500
# 2344/2344 - 0s - loss: 0.0260 - mean_absolute_percentage_error: 10.4492 - val_loss: 0.0271 - val_mean_absolute_percentage_error: 11.1764
# Epoch 290/500
# 2344/2344 - 0s - loss: 0.0233 - mean_absolute_percentage_error: 10.2037 - val_loss: 0.0266 - val_mean_absolute_percentage_error: 11.1986
# Epoch 291/500
# 2344/2344 - 0s - loss: 0.0258 - mean_absolute_percentage_error: 10.2973 - val_loss: 0.0264 - val_mean_absolute_percentage_error: 11.2356
# Epoch 292/500
# 2344/2344 - 0s - loss: 0.0243 - mean_absolute_percentage_error: 10.3947 - val_loss: 0.0265 - val_mean_absolute_percentage_error: 11.1493
# Epoch 293/500
# 2344/2344 - 0s - loss: 0.0240 - mean_absolute_percentage_error: 10.2449 - val_loss: 0.0265 - val_mean_absolute_percentage_error: 11.0785
# Epoch 294/500
# 2344/2344 - 0s - loss: 0.0237 - mean_absolute_percentage_error: 9.9939 - val_loss: 0.0259 - val_mean_absolute_percentage_error: 10.9960
# Epoch 295/500
# 2344/2344 - 0s - loss: 0.0247 - mean_absolute_percentage_error: 10.3029 - val_loss: 0.0264 - val_mean_absolute_percentage_error: 11.1549
# Epoch 296/500
# 2344/2344 - 0s - loss: 0.0233 - mean_absolute_percentage_error: 10.1482 - val_loss: 0.0253 - val_mean_absolute_percentage_error: 11.0872
# Epoch 297/500
# 2344/2344 - 0s - loss: 0.0235 - mean_absolute_percentage_error: 10.3309 - val_loss: 0.0255 - val_mean_absolute_percentage_error: 11.1754
# Epoch 298/500
# 2344/2344 - 0s - loss: 0.0247 - mean_absolute_percentage_error: 9.9774 - val_loss: 0.0264 - val_mean_absolute_percentage_error: 11.0579
# Epoch 299/500
# 2344/2344 - 0s - loss: 0.0304 - mean_absolute_percentage_error: 10.1957 - val_loss: 0.0250 - val_mean_absolute_percentage_error: 10.8278
# Epoch 300/500
# 2344/2344 - 0s - loss: 0.0258 - mean_absolute_percentage_error: 10.2592 - val_loss: 0.0249 - val_mean_absolute_percentage_error: 10.9340
# Epoch 301/500
# 2344/2344 - 0s - loss: 0.0263 - mean_absolute_percentage_error: 9.9825 - val_loss: 0.0255 - val_mean_absolute_percentage_error: 11.0184
# Epoch 302/500
# 2344/2344 - 0s - loss: 0.0237 - mean_absolute_percentage_error: 10.1102 - val_loss: 0.0262 - val_mean_absolute_percentage_error: 11.1420
# Epoch 303/500
# 2344/2344 - 0s - loss: 0.0251 - mean_absolute_percentage_error: 10.0401 - val_loss: 0.0259 - val_mean_absolute_percentage_error: 10.8635
# Epoch 304/500
# 2344/2344 - 0s - loss: 0.0257 - mean_absolute_percentage_error: 10.2631 - val_loss: 0.0251 - val_mean_absolute_percentage_error: 10.7800
# Epoch 305/500
# 2344/2344 - 0s - loss: 0.0266 - mean_absolute_percentage_error: 9.9996 - val_loss: 0.0261 - val_mean_absolute_percentage_error: 11.0698
# Epoch 306/500
# 2344/2344 - 0s - loss: 0.0257 - mean_absolute_percentage_error: 9.9021 - val_loss: 0.0265 - val_mean_absolute_percentage_error: 11.1909
# Epoch 307/500
# 2344/2344 - 0s - loss: 0.0256 - mean_absolute_percentage_error: 10.1245 - val_loss: 0.0259 - val_mean_absolute_percentage_error: 10.9567
# Epoch 308/500
# 2344/2344 - 0s - loss: 0.0243 - mean_absolute_percentage_error: 9.9344 - val_loss: 0.0259 - val_mean_absolute_percentage_error: 10.8930
# Epoch 309/500
# 2344/2344 - 0s - loss: 0.0240 - mean_absolute_percentage_error: 9.9494 - val_loss: 0.0272 - val_mean_absolute_percentage_error: 11.0208
# Epoch 310/500
# 2344/2344 - 0s - loss: 0.0240 - mean_absolute_percentage_error: 10.0339 - val_loss: 0.0263 - val_mean_absolute_percentage_error: 11.0361
# Epoch 311/500
# 2344/2344 - 0s - loss: 0.0254 - mean_absolute_percentage_error: 10.0919 - val_loss: 0.0260 - val_mean_absolute_percentage_error: 11.0009
# Epoch 312/500
# 2344/2344 - 0s - loss: 0.0229 - mean_absolute_percentage_error: 10.0065 - val_loss: 0.0259 - val_mean_absolute_percentage_error: 10.9842
# Epoch 313/500
# 2344/2344 - 0s - loss: 0.0213 - mean_absolute_percentage_error: 10.1604 - val_loss: 0.0255 - val_mean_absolute_percentage_error: 11.0148
# Epoch 314/500
# 2344/2344 - 0s - loss: 0.0213 - mean_absolute_percentage_error: 9.8776 - val_loss: 0.0253 - val_mean_absolute_percentage_error: 10.8683
# Epoch 315/500
# 2344/2344 - 0s - loss: 0.0223 - mean_absolute_percentage_error: 9.8152 - val_loss: 0.0247 - val_mean_absolute_percentage_error: 10.5341
# Epoch 316/500
# 2344/2344 - 0s - loss: 0.0248 - mean_absolute_percentage_error: 9.9932 - val_loss: 0.0254 - val_mean_absolute_percentage_error: 10.5295
# Epoch 317/500
# 2344/2344 - 0s - loss: 0.0220 - mean_absolute_percentage_error: 9.9909 - val_loss: 0.0252 - val_mean_absolute_percentage_error: 10.7045
# Epoch 318/500
# 2344/2344 - 0s - loss: 0.0219 - mean_absolute_percentage_error: 9.7088 - val_loss: 0.0242 - val_mean_absolute_percentage_error: 10.8020
# Epoch 319/500
# ...
# Epoch 394/500
# 2344/2344 - 0s - loss: 0.0202 - mean_absolute_percentage_error: 8.8626 - val_loss: 0.0207 - val_mean_absolute_percentage_error: 9.7428
# Epoch 395/500
# 2344/2344 - 0s - loss: 0.0213 - mean_absolute_percentage_error: 9.1010 - val_loss: 0.0207 - val_mean_absolute_percentage_error: 9.6805
# Epoch 396/500
# 2344/2344 - 0s - loss: 0.0197 - mean_absolute_percentage_error: 8.9708 - val_loss: 0.0209 - val_mean_absolute_percentage_error: 9.6888
# Epoch 397/500
# 2344/2344 - 0s - loss: 0.0205 - mean_absolute_percentage_error: 8.9637 - val_loss: 0.0208 - val_mean_absolute_percentage_error: 9.6331
# Epoch 398/500
# 2344/2344 - 0s - loss: 0.0197 - mean_absolute_percentage_error: 9.0721 - val_loss: 0.0206 - val_mean_absolute_percentage_error: 9.6136
# Epoch 399/500
# 2344/2344 - 0s - loss: 0.0190 - mean_absolute_percentage_error: 9.0746 - val_loss: 0.0204 - val_mean_absolute_percentage_error: 9.7489
# Epoch 400/500
# 2344/2344 - 0s - loss: 0.0182 - mean_absolute_percentage_error: 9.0874 - val_loss: 0.0205 - val_mean_absolute_percentage_error: 9.7965
# Epoch 401/500
# 2344/2344 - 0s - loss: 0.0178 - mean_absolute_percentage_error: 9.1309 - val_loss: 0.0208 - val_mean_absolute_percentage_error: 9.8749
# Epoch 402/500
# 2344/2344 - 0s - loss: 0.0192 - mean_absolute_percentage_error: 9.0110 - val_loss: 0.0206 - val_mean_absolute_percentage_error: 9.7132
# Epoch 403/500
# 2344/2344 - 0s - loss: 0.0187 - mean_absolute_percentage_error: 8.9509 - val_loss: 0.0204 - val_mean_absolute_percentage_error: 9.7013
# Epoch 404/500
# 2344/2344 - 0s - loss: 0.0217 - mean_absolute_percentage_error: 9.2703 - val_loss: 0.0201 - val_mean_absolute_percentage_error: 9.9088
# Epoch 405/500
# 2344/2344 - 0s - loss: 0.0219 - mean_absolute_percentage_error: 9.2613 - val_loss: 0.0204 - val_mean_absolute_percentage_error: 10.1635
# Epoch 406/500
# 2344/2344 - 0s - loss: 0.0216 - mean_absolute_percentage_error: 9.0246 - val_loss: 0.0201 - val_mean_absolute_percentage_error: 9.9384
# Epoch 407/500
# 2344/2344 - 0s - loss: 0.0179 - mean_absolute_percentage_error: 8.6544 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 9.2550
# Epoch 408/500
# 2344/2344 - 0s - loss: 0.0191 - mean_absolute_percentage_error: 9.0531 - val_loss: 0.0202 - val_mean_absolute_percentage_error: 9.6084
# Epoch 409/500
# 2344/2344 - 0s - loss: 0.0192 - mean_absolute_percentage_error: 8.8382 - val_loss: 0.0207 - val_mean_absolute_percentage_error: 9.8941
# Epoch 410/500
# 2344/2344 - 0s - loss: 0.0241 - mean_absolute_percentage_error: 9.0097 - val_loss: 0.0200 - val_mean_absolute_percentage_error: 9.7077
# Epoch 411/500
# 2344/2344 - 0s - loss: 0.0246 - mean_absolute_percentage_error: 9.0422 - val_loss: 0.0197 - val_mean_absolute_percentage_error: 9.4277
# Epoch 412/500
# 2344/2344 - 0s - loss: 0.0207 - mean_absolute_percentage_error: 9.0889 - val_loss: 0.0203 - val_mean_absolute_percentage_error: 9.5005
# Epoch 413/500
# 2344/2344 - 0s - loss: 0.0180 - mean_absolute_percentage_error: 8.8649 - val_loss: 0.0205 - val_mean_absolute_percentage_error: 9.8590
# Epoch 414/500
# 2344/2344 - 0s - loss: 0.0224 - mean_absolute_percentage_error: 9.1124 - val_loss: 0.0202 - val_mean_absolute_percentage_error: 9.5909
# Epoch 415/500
# 2344/2344 - 0s - loss: 0.0189 - mean_absolute_percentage_error: 9.2648 - val_loss: 0.0205 - val_mean_absolute_percentage_error: 9.5488
# Epoch 416/500
# 2344/2344 - 0s - loss: 0.0242 - mean_absolute_percentage_error: 9.0929 - val_loss: 0.0202 - val_mean_absolute_percentage_error: 9.5077
# Epoch 417/500
# 2344/2344 - 0s - loss: 0.0209 - mean_absolute_percentage_error: 8.9183 - val_loss: 0.0208 - val_mean_absolute_percentage_error: 9.3982
# Epoch 418/500
# 2344/2344 - 0s - loss: 0.0206 - mean_absolute_percentage_error: 9.0708 - val_loss: 0.0205 - val_mean_absolute_percentage_error: 9.4307
# Epoch 419/500
# 2344/2344 - 0s - loss: 0.0239 - mean_absolute_percentage_error: 9.1026 - val_loss: 0.0200 - val_mean_absolute_percentage_error: 9.5524
# Epoch 420/500
# 2344/2344 - 0s - loss: 0.0187 - mean_absolute_percentage_error: 9.1858 - val_loss: 0.0204 - val_mean_absolute_percentage_error: 9.5514
# Epoch 421/500
# 2344/2344 - 0s - loss: 0.0210 - mean_absolute_percentage_error: 8.8239 - val_loss: 0.0207 - val_mean_absolute_percentage_error: 9.4467
# Epoch 422/500
# 2344/2344 - 0s - loss: 0.0213 - mean_absolute_percentage_error: 9.0270 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 9.3085
# Epoch 423/500
# 2344/2344 - 0s - loss: 0.0187 - mean_absolute_percentage_error: 9.0041 - val_loss: 0.0200 - val_mean_absolute_percentage_error: 9.4586
# Epoch 424/500
# 2344/2344 - 0s - loss: 0.0172 - mean_absolute_percentage_error: 8.7872 - val_loss: 0.0202 - val_mean_absolute_percentage_error: 9.4184
# Epoch 425/500
# 2344/2344 - 0s - loss: 0.0193 - mean_absolute_percentage_error: 8.8096 - val_loss: 0.0203 - val_mean_absolute_percentage_error: 9.3462
# Epoch 426/500
# 2344/2344 - 0s - loss: 0.0195 - mean_absolute_percentage_error: 9.2356 - val_loss: 0.0198 - val_mean_absolute_percentage_error: 9.2717
# Epoch 427/500
# 2344/2344 - 0s - loss: 0.0188 - mean_absolute_percentage_error: 8.8879 - val_loss: 0.0202 - val_mean_absolute_percentage_error: 9.4162
# Epoch 428/500
# 2344/2344 - 0s - loss: 0.0207 - mean_absolute_percentage_error: 8.8397 - val_loss: 0.0204 - val_mean_absolute_percentage_error: 9.4655
# Epoch 429/500
# 2344/2344 - 0s - loss: 0.0194 - mean_absolute_percentage_error: 8.8969 - val_loss: 0.0205 - val_mean_absolute_percentage_error: 9.6144
# Epoch 430/500
# 2344/2344 - 0s - loss: 0.0193 - mean_absolute_percentage_error: 8.9521 - val_loss: 0.0200 - val_mean_absolute_percentage_error: 9.5530
# Epoch 431/500
# 2344/2344 - 0s - loss: 0.0189 - mean_absolute_percentage_error: 8.8384 - val_loss: 0.0198 - val_mean_absolute_percentage_error: 9.5068
# Epoch 432/500
# 2344/2344 - 0s - loss: 0.0203 - mean_absolute_percentage_error: 8.8106 - val_loss: 0.0201 - val_mean_absolute_percentage_error: 9.4607
# Epoch 433/500
# 2344/2344 - 0s - loss: 0.0179 - mean_absolute_percentage_error: 8.7668 - val_loss: 0.0202 - val_mean_absolute_percentage_error: 9.5626
# Epoch 434/500
# 2344/2344 - 0s - loss: 0.0192 - mean_absolute_percentage_error: 8.9306 - val_loss: 0.0197 - val_mean_absolute_percentage_error: 9.5625
# Epoch 435/500
# 2344/2344 - 0s - loss: 0.0173 - mean_absolute_percentage_error: 8.6767 - val_loss: 0.0198 - val_mean_absolute_percentage_error: 9.5216
# Epoch 436/500
# 2344/2344 - 0s - loss: 0.0205 - mean_absolute_percentage_error: 8.9612 - val_loss: 0.0198 - val_mean_absolute_percentage_error: 9.3146
# Epoch 437/500
# 2344/2344 - 0s - loss: 0.0189 - mean_absolute_percentage_error: 8.8250 - val_loss: 0.0203 - val_mean_absolute_percentage_error: 9.5056
# Epoch 438/500
# 2344/2344 - 0s - loss: 0.0202 - mean_absolute_percentage_error: 8.9654 - val_loss: 0.0203 - val_mean_absolute_percentage_error: 9.7130
# Epoch 439/500
# 2344/2344 - 0s - loss: 0.0187 - mean_absolute_percentage_error: 8.9936 - val_loss: 0.0201 - val_mean_absolute_percentage_error: 9.5520
# Epoch 440/500
# 2344/2344 - 0s - loss: 0.0205 - mean_absolute_percentage_error: 8.9542 - val_loss: 0.0198 - val_mean_absolute_percentage_error: 9.4855
# Epoch 441/500
# 2344/2344 - 0s - loss: 0.0206 - mean_absolute_percentage_error: 9.0438 - val_loss: 0.0195 - val_mean_absolute_percentage_error: 9.5337
# Epoch 442/500
# 2344/2344 - 0s - loss: 0.0215 - mean_absolute_percentage_error: 8.9472 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 9.3512
# Epoch 443/500
# 2344/2344 - 0s - loss: 0.0176 - mean_absolute_percentage_error: 8.7341 - val_loss: 0.0199 - val_mean_absolute_percentage_error: 9.2856
# Epoch 444/500
# 2344/2344 - 0s - loss: 0.0164 - mean_absolute_percentage_error: 8.6418 - val_loss: 0.0195 - val_mean_absolute_percentage_error: 9.4579
# Epoch 445/500
# 2344/2344 - 0s - loss: 0.0186 - mean_absolute_percentage_error: 8.7696 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 9.5023
# Epoch 446/500
# 2344/2344 - 0s - loss: 0.0194 - mean_absolute_percentage_error: 8.6881 - val_loss: 0.0195 - val_mean_absolute_percentage_error: 9.2079
# Epoch 447/500
# 2344/2344 - 0s - loss: 0.0191 - mean_absolute_percentage_error: 8.7487 - val_loss: 0.0202 - val_mean_absolute_percentage_error: 9.1951
# Epoch 448/500
# 2344/2344 - 0s - loss: 0.0204 - mean_absolute_percentage_error: 8.8334 - val_loss: 0.0200 - val_mean_absolute_percentage_error: 9.3728
# Epoch 449/500
# 2344/2344 - 0s - loss: 0.0211 - mean_absolute_percentage_error: 9.1066 - val_loss: 0.0203 - val_mean_absolute_percentage_error: 9.5807
# Epoch 450/500
# 2344/2344 - 0s - loss: 0.0168 - mean_absolute_percentage_error: 8.8644 - val_loss: 0.0202 - val_mean_absolute_percentage_error: 9.5355
# Epoch 451/500
# 2344/2344 - 0s - loss: 0.0174 - mean_absolute_percentage_error: 8.8041 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 9.2272
# Epoch 452/500
# 2344/2344 - 0s - loss: 0.0170 - mean_absolute_percentage_error: 8.7703 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 9.3720
# Epoch 453/500
# 2344/2344 - 0s - loss: 0.0186 - mean_absolute_percentage_error: 8.9104 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 9.5068
# Epoch 454/500
# 2344/2344 - 0s - loss: 0.0210 - mean_absolute_percentage_error: 8.7471 - val_loss: 0.0191 - val_mean_absolute_percentage_error: 9.4010
# Epoch 455/500
# 2344/2344 - 0s - loss: 0.0191 - mean_absolute_percentage_error: 8.6293 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 9.2011
# Epoch 456/500
# 2344/2344 - 0s - loss: 0.0187 - mean_absolute_percentage_error: 8.7223 - val_loss: 0.0195 - val_mean_absolute_percentage_error: 9.2888
# Epoch 457/500
# 2344/2344 - 0s - loss: 0.0184 - mean_absolute_percentage_error: 8.7976 - val_loss: 0.0197 - val_mean_absolute_percentage_error: 9.6580
# Epoch 458/500
# 2344/2344 - 0s - loss: 0.0159 - mean_absolute_percentage_error: 8.7250 - val_loss: 0.0200 - val_mean_absolute_percentage_error: 9.4664
# Epoch 459/500
# 2344/2344 - 0s - loss: 0.0192 - mean_absolute_percentage_error: 8.6305 - val_loss: 0.0197 - val_mean_absolute_percentage_error: 9.2210
# Epoch 460/500
# 2344/2344 - 0s - loss: 0.0184 - mean_absolute_percentage_error: 8.7847 - val_loss: 0.0191 - val_mean_absolute_percentage_error: 9.2698
# Epoch 461/500
# 2344/2344 - 0s - loss: 0.0220 - mean_absolute_percentage_error: 8.9021 - val_loss: 0.0201 - val_mean_absolute_percentage_error: 9.4389
# Epoch 462/500
# 2344/2344 - 0s - loss: 0.0194 - mean_absolute_percentage_error: 8.6213 - val_loss: 0.0204 - val_mean_absolute_percentage_error: 9.2761
# Epoch 463/500
# 2344/2344 - 0s - loss: 0.0203 - mean_absolute_percentage_error: 8.8208 - val_loss: 0.0199 - val_mean_absolute_percentage_error: 9.2090
# Epoch 464/500
# 2344/2344 - 0s - loss: 0.0200 - mean_absolute_percentage_error: 9.0019 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 9.2466
# Epoch 465/500
# 2344/2344 - 0s - loss: 0.0174 - mean_absolute_percentage_error: 8.8622 - val_loss: 0.0195 - val_mean_absolute_percentage_error: 9.3996
# Epoch 466/500
# 2344/2344 - 0s - loss: 0.0174 - mean_absolute_percentage_error: 8.5814 - val_loss: 0.0193 - val_mean_absolute_percentage_error: 9.4282
# Epoch 467/500
# 2344/2344 - 0s - loss: 0.0174 - mean_absolute_percentage_error: 8.6370 - val_loss: 0.0195 - val_mean_absolute_percentage_error: 9.3053
# Epoch 468/500
# 2344/2344 - 0s - loss: 0.0181 - mean_absolute_percentage_error: 8.6887 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 9.2568
# Epoch 469/500
# 2344/2344 - 0s - loss: 0.0166 - mean_absolute_percentage_error: 8.6677 - val_loss: 0.0188 - val_mean_absolute_percentage_error: 9.3277
# Epoch 470/500
# 2344/2344 - 0s - loss: 0.0212 - mean_absolute_percentage_error: 9.0099 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 9.3398
# Epoch 471/500
# 2344/2344 - 0s - loss: 0.0167 - mean_absolute_percentage_error: 8.6421 - val_loss: 0.0201 - val_mean_absolute_percentage_error: 9.3106
# Epoch 472/500
# 2344/2344 - 0s - loss: 0.0163 - mean_absolute_percentage_error: 8.6093 - val_loss: 0.0191 - val_mean_absolute_percentage_error: 9.3063
# Epoch 473/500
# 2344/2344 - 0s - loss: 0.0176 - mean_absolute_percentage_error: 8.8452 - val_loss: 0.0190 - val_mean_absolute_percentage_error: 9.3324
# Epoch 474/500
# 2344/2344 - 0s - loss: 0.0188 - mean_absolute_percentage_error: 8.7468 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 9.2528
# Epoch 475/500
# 2344/2344 - 0s - loss: 0.0202 - mean_absolute_percentage_error: 8.6589 - val_loss: 0.0197 - val_mean_absolute_percentage_error: 9.2192
# Epoch 476/500
# 2344/2344 - 0s - loss: 0.0160 - mean_absolute_percentage_error: 8.4794 - val_loss: 0.0189 - val_mean_absolute_percentage_error: 9.0463
# Epoch 477/500
# 2344/2344 - 0s - loss: 0.0170 - mean_absolute_percentage_error: 8.6872 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 9.1358
# Epoch 478/500
# 2344/2344 - 0s - loss: 0.0156 - mean_absolute_percentage_error: 8.6552 - val_loss: 0.0199 - val_mean_absolute_percentage_error: 9.3354
# Epoch 479/500
# 2344/2344 - 0s - loss: 0.0178 - mean_absolute_percentage_error: 8.6298 - val_loss: 0.0191 - val_mean_absolute_percentage_error: 9.2534
# Epoch 480/500
# 2344/2344 - 0s - loss: 0.0188 - mean_absolute_percentage_error: 8.7485 - val_loss: 0.0192 - val_mean_absolute_percentage_error: 9.1502
# Epoch 481/500
# 2344/2344 - 0s - loss: 0.0163 - mean_absolute_percentage_error: 8.5035 - val_loss: 0.0193 - val_mean_absolute_percentage_error: 9.1973
# Epoch 482/500
# 2344/2344 - 0s - loss: 0.0235 - mean_absolute_percentage_error: 8.7708 - val_loss: 0.0188 - val_mean_absolute_percentage_error: 9.1220
# Epoch 483/500
# 2344/2344 - 0s - loss: 0.0208 - mean_absolute_percentage_error: 8.6059 - val_loss: 0.0189 - val_mean_absolute_percentage_error: 9.1534
# Epoch 484/500
# 2344/2344 - 0s - loss: 0.0154 - mean_absolute_percentage_error: 8.4119 - val_loss: 0.0190 - val_mean_absolute_percentage_error: 9.2791
# Epoch 485/500
# 2344/2344 - 0s - loss: 0.0188 - mean_absolute_percentage_error: 8.5515 - val_loss: 0.0195 - val_mean_absolute_percentage_error: 9.1150
# Epoch 486/500
# 2344/2344 - 0s - loss: 0.0191 - mean_absolute_percentage_error: 8.5194 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 9.1116
# Epoch 487/500
# 2344/2344 - 0s - loss: 0.0184 - mean_absolute_percentage_error: 8.5743 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 8.9889
# Epoch 488/500
# 2344/2344 - 0s - loss: 0.0184 - mean_absolute_percentage_error: 8.7437 - val_loss: 0.0198 - val_mean_absolute_percentage_error: 8.9681
# Epoch 489/500
# 2344/2344 - 0s - loss: 0.0162 - mean_absolute_percentage_error: 8.5310 - val_loss: 0.0209 - val_mean_absolute_percentage_error: 9.3442
# Epoch 490/500
# 2344/2344 - 0s - loss: 0.0193 - mean_absolute_percentage_error: 8.5965 - val_loss: 0.0209 - val_mean_absolute_percentage_error: 9.3505
# Epoch 491/500
# 2344/2344 - 0s - loss: 0.0156 - mean_absolute_percentage_error: 8.4527 - val_loss: 0.0197 - val_mean_absolute_percentage_error: 8.9977
# Epoch 492/500
# 2344/2344 - 0s - loss: 0.0176 - mean_absolute_percentage_error: 8.7510 - val_loss: 0.0189 - val_mean_absolute_percentage_error: 9.0575
# Epoch 493/500
# 2344/2344 - 0s - loss: 0.0178 - mean_absolute_percentage_error: 8.7752 - val_loss: 0.0195 - val_mean_absolute_percentage_error: 9.1675
# Epoch 494/500
# 2344/2344 - 0s - loss: 0.0149 - mean_absolute_percentage_error: 8.3894 - val_loss: 0.0198 - val_mean_absolute_percentage_error: 9.1941
# Epoch 495/500
# 2344/2344 - 0s - loss: 0.0161 - mean_absolute_percentage_error: 8.5026 - val_loss: 0.0195 - val_mean_absolute_percentage_error: 9.1667
# Epoch 496/500
# 2344/2344 - 0s - loss: 0.0154 - mean_absolute_percentage_error: 8.2961 - val_loss: 0.0196 - val_mean_absolute_percentage_error: 9.0048
# Epoch 497/500
# 2344/2344 - 0s - loss: 0.0167 - mean_absolute_percentage_error: 8.5229 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 8.8742
# Epoch 498/500
# 2344/2344 - 0s - loss: 0.0159 - mean_absolute_percentage_error: 8.4700 - val_loss: 0.0193 - val_mean_absolute_percentage_error: 9.2293
# Epoch 499/500
# 2344/2344 - 0s - loss: 0.0191 - mean_absolute_percentage_error: 8.6857 - val_loss: 0.0198 - val_mean_absolute_percentage_error: 9.3774
# Epoch 500/500
# 2344/2344 - 0s - loss: 0.0162 - mean_absolute_percentage_error: 8.3582 - val_loss: 0.0203 - val_mean_absolute_percentage_error: 8.9614

# %% [markdown]
# After 500 epochs, our predictions are off by less than 10% on average. This is pretty good.

# %% [markdown]
# ## Decoding predictions
#
# Because our targets were median-normalized, we need to multiply them back by the median value to get the dollar price.

# %%
preds = model.predict(val_features[:10])
preds *= targets_median
preds = [int(p) for p in preds]
print('Price predictions for first 10 samples:', preds)
print('Actual prices:', [int(p) for p in val_targets[:10] * targets_median])
# Out:
# Price predictions for first 10 samples: [221236, 166130, 163822, 214029, 171229, 200792, 248598, 160878, 172839, 258069]
# Actual prices: [235000, 190000, 169000, 241500, 188899, 207500, 250000, 179900, 172000, 294323]
